# %% [markdown]
# ## Explore abnormal distribution of OpChs
#
# #### Shu, 20260122

# %% [markdown]
# <br />
# <br />
#
# ### EXPECTED OpChs for Events before / after TPC cuts:

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

import os


# Path to the output file produced earlier
initial_opch_file = "./opch_explore/opchs_initial.txt"
filtered_opch_file = './opch_explore/opchs_filtered.txt'

# Read all OpCh values into a 1D list
opch_initial = []
opch_filtered = []


with open(initial_opch_file, "r") as f:
    for line in f:
        line = line.strip()
        if line:
            opch_initial.append(int(line))

with open(filtered_opch_file, "r") as f:
    for line in f:
        line = line.strip()
        if line:
            opch_filtered.append(int(line))


# Inspect result
print("Size of initial opchs : ", len(opch_initial))
print("Size of filtered opchs: ", len(opch_filtered))
# Out:
# Size of initial opchs :  2591613
# Size of filtered opchs:  408573

# %%
# Plotting the histogram (X distribution)---------------
plt.figure(figsize=(4,3),dpi=400)

#Define the range and bin width
bin_width = 1
range_min = 0
range_max = 160
bins = np.arange(range_min, range_max + bin_width, bin_width)

#plt.plot([4, 4], [0, 15000], color="magenta", linewidth=1.5, linestyle='--')

plt.hist(opch_initial, bins=bins, range=(range_min, range_max), edgecolor='black', 
         histtype='step', linewidth=0.8, label='Before ANY Cut')
plt.hist(opch_filtered, bins=bins, range=(range_min, range_max), edgecolor='red', 
         histtype='step', linewidth=0.8, label='After TPC Cut')

plt.legend(loc='upper center', bbox_to_anchor=(0.75, 0.95), fontsize=10, markerscale=6, ncol=1, prop={'size': 7})

plt.xlim(0, 160)
plt.xlabel('Expected Optical Channel Label', labelpad=2, fontsize=8)
plt.ylabel('#Counts', labelpad=1, fontsize=8)
plt.ylim(0.1, 150000)
#plt.yscale('log')
plt.title("Not Very Helpful ...")
plt.tick_params(labelsize=7)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)

plt.show()

# %% [markdown]
# <br />
#
# ### Valid Opchs Before TPC Cuts (10 Michelt0 files):

# %%
# Path to the output file produced earlier
opch_michelT0_file = "./opch_explore/opch_fromMichelT0.txt"

# Read all OpCh values into a 1D list
opch_michelT0 = []

with open(opch_michelT0_file, "r") as f:
    for line in f:
        line = line.strip()
        if line:
            opch_michelT0.append(int(line))

# Inspect result
print("Size of opch_MichelT0 : ", len(opch_michelT0))
# Out:
# Size of opch_MichelT0 :  488181

# %%
# Plotting the histogram (X distribution)---------------
plt.figure(figsize=(4,3),dpi=400)

#Define the range and bin width
bin_width = 1
range_min = 0
range_max = 160
bins = np.arange(range_min, range_max + bin_width, bin_width)

#plt.plot([4, 4], [0, 15000], color="magenta", linewidth=1.5, linestyle='--')

plt.hist(opch_michelT0, bins=bins, range=(range_min, range_max), edgecolor='black', 
         histtype='step', linewidth=0.8, label='Before Any Cut (from Michelt0)')

plt.legend(loc='upper center', bbox_to_anchor=(0.65, 0.95), fontsize=10, markerscale=6, ncol=1, prop={'size': 7})

plt.xlim(0, 160)
plt.xlabel('Optical Channel', labelpad=2, fontsize=8)
plt.ylabel('#Counts', labelpad=1, fontsize=8)
plt.ylim(0.1, 10000)
#plt.yscale('log')
#plt.title("Not Very Helpful ...")
plt.tick_params(labelsize=7)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)

plt.show()

# %% [markdown]
# <br />
#
# ### Valid Opchs After TPC Cuts (extracted_files & wvf_merged):

# %%
# Path to the output file produced earlier
opch_extractedFiles_file = "./opch_explore/opch_extractedFiles.txt"

# Read all OpCh values into a 1D list
opch_extractedFiles = []

with open(opch_extractedFiles_file, "r") as f:
    for line in f:
        line = line.strip()
        if line:
            opch_extractedFiles.append(int(line))

# Inspect result
print("Size of opch_extractedFiles : ", len(opch_extractedFiles))




opch_wvfMerged_file = "./opch_explore/opch_wvfMerged.txt"

# Read all OpCh values into a 1D list
opch_wvfMerged = []

with open(opch_wvfMerged_file, "r") as f:
    for line in f:
        line = line.strip()
        if line:
            opch_wvfMerged.append(int(line))

# Inspect result
print("Size of opch_wvfMerged : ", len(opch_wvfMerged))





# Here are results from 28116=======================================
# Path to the output file produced earlier
opch_extractedFiles_file_28116 = "./opch_explore/opch_extractedFiles_28116.txt"

# Read all OpCh values into a 1D list
opch_extractedFiles_28116 = []

with open(opch_extractedFiles_file_28116, "r") as f:
    for line in f:
        line = line.strip()
        if line:
            opch_extractedFiles_28116.append(int(line))

# Inspect result
print("Size of opch_extractedFiles_28116 : ", len(opch_extractedFiles_28116))




opch_wvfMerged_file_28116 = "./opch_explore/opch_wvfMerged_28116.txt"

# Read all OpCh values into a 1D list
opch_wvfMerged_28116 = []

with open(opch_wvfMerged_file_28116, "r") as f:
    for line in f:
        line = line.strip()
        if line:
            opch_wvfMerged_28116.append(int(line))

# Inspect result
print("Size of opch_wvfMerged : ", len(opch_wvfMerged_28116))
# Out:
# Size of opch_extractedFiles :  160695
# Size of opch_wvfMerged :  116736
# Size of opch_extractedFiles_28116 :  134825
# Size of opch_wvfMerged :  101284

# %%
# Plotting the histogram (X distribution)---------------
plt.figure(figsize=(4,3),dpi=400)

#Define the range and bin width
bin_width = 1
range_min = 0
range_max = 160
bins = np.arange(range_min, range_max + bin_width, bin_width)

#plt.plot([4, 4], [0, 15000], color="magenta", linewidth=1.5, linestyle='--')

plt.hist(opch_extractedFiles, bins=bins, range=(range_min, range_max), edgecolor='black', 
         histtype='step', linewidth=0.8, label='Extracted Files (27980)')
#plt.hist(opch_wvfMerged, bins=bins, range=(range_min, range_max), edgecolor='red', 
#         histtype='step', linewidth=0.8, label='Wvf Merged (27980)')

plt.hist(opch_extractedFiles_28116, bins=bins, range=(range_min, range_max), edgecolor='blue', 
         histtype='step', linewidth=0.8, label='Extracted Files (28116)')
#plt.hist(opch_wvfMerged_28116, bins=bins, range=(range_min, range_max), edgecolor='green', 
#         histtype='step', linewidth=0.8, label='Wvf Merged (28116)')


plt.legend(loc='upper center', bbox_to_anchor=(0.65, 0.95), fontsize=10, markerscale=6, ncol=1, prop={'size': 7})

plt.xlim(0, 160)
plt.xlabel('Optical Channel', labelpad=2, fontsize=8)
plt.ylabel('#Counts', labelpad=1, fontsize=8)
plt.ylim(0.1, 10000)
#plt.yscale('log')
#plt.title("Not Very Helpful ...")
plt.tick_params(labelsize=7)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)

plt.show()
