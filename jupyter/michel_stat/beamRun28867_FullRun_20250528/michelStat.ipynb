# %% [markdown]
# # Statistics for Michel electron candidate (28867 full run)
#
# ### Created by Shu, 20250529---

# %% [markdown]
# #### Focus here is PDS processing (Previous TPC processing [Space, MS, MH cuts] is at beamRun28867_FullRun)
#
# #### Compared to previous result, opch35 is included

# %% [markdown]
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
#
#
# ## Wvf Coincidence Cut (Full run / 5,340 events) (based on Decon wvfs):

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D


# Specify the file name
#read data---
previous = []
new = []


with open('./statResult/count_wvfCoin_merged.txt', 'r') as filehandle:#previous new result, from beamRun28867_FullRun
    for line in filehandle:
        currentPlace = line[:-1]
        previous.append(float(currentPlace))

with open('./statResult/print_wvfCoin_count.txt', 'r') as filehandle:  # opch35 added---
    for line in filehandle:
        line = line.strip()  # remove trailing newline and spaces
        if ':' in line:
            value = line.split(':')[-1].strip()  # get value after colon
            new.append(float(value))


print("Intial event candidates     :  5340")
print("Length of Previous result   : ", len(previous))
print("Length of New (opch35 added): ", len(new))

#For 5340 candidates:
#previous: /Users/shuaixiangzhang/Work/current/FNAL_Work2024/michel_e/t0_tagging/pdhd_DATA_v2/analyze_pdhd_DATA_v2/ \
#         analyze/v2_main/data_src_decon_FullRun/print_wvfCoin.txt; search for "No valid histograms found"
#new: /Users/shuaixiangzhang/Work/current/FNAL_Work2024/michel_e/t0_tagging/pdhd_DATA_v2/analyze_pdhd_DATA_v2/ \
#        analyze/v2_main/data_src_decon_FullRun/print_wvfCoin_new.txt; search for "No valid histograms found"
previous.extend([0] * 514)
new.extend([0] * 512)

print("Length of previous (+ 514 0s): ", len(previous))
print("Length of new: (+ 514 0s)    : ", len(new))
# Out:
# Intial event candidates     :  5340
# Length of Previous result   :  5694
# Length of New (opch35 added):  5684
# Length of previous (+ 514 0s):  6208
# Length of new: (+ 514 0s)    :  6196

# %% [markdown]
# ##### A quick remark: Here we have fewer candidates for the result including opch35. This is because opch35 might break the condition that there will be two track condidates with the same maximum coincidence!

# %%
import matplotlib.pyplot as plt
import numpy as np

# Simple statistics------
num_previous_ge5 = sum(1 for x in previous if x >= 5)
num_new_ge5 = sum(1 for x in new if x >= 5)

# Event candidates (after space, MS & MH cuts): # = 1670
print("\nprevious (#wvf >= 5): ", num_previous_ge5, "({:.2f}%)".format(num_previous_ge5/5340*100))
print("new  (#wvf >= 5): ", num_new_ge5, "({:.2f}%)".format(num_new_ge5/5340*100))

# Plotting the histogram (X distribution)---------------
plt.figure(figsize=(4, 3), dpi=400)

# Define the range and bin width
bin_width = 1
range_min = 0
range_max = 11
bins = np.arange(range_min, range_max + bin_width, bin_width)

# Compute histogram values
hist_previous, _ = np.histogram(previous, bins=bins, range=(range_min, range_max))
hist_new, _ = np.histogram(new, bins=bins, range=(range_min, range_max))
bin_centers = (bins[:-1] + bins[1:]) / 2

# Print bin-by-bin comparison
print("\nBin-by-bin comparison:")
for i, center in enumerate(bin_centers):
    diff = hist_new[i] - hist_previous[i]
    print(f"Bin {int(center)}: Previous: {hist_previous[i]}; New: {hist_new[i]}; Difference: {diff}")

# Plot vertical line at threshold
plt.plot([5, 5], [0, 1200], color="magenta", linewidth=1.5, linestyle='--')

# Draw histograms
plt.hist(previous, bins=bins, range=(range_min, range_max), edgecolor='red',
         histtype='step', linewidth=0.8, label='previous Result')
plt.hist(new, bins=bins, range=(range_min, range_max), edgecolor='green',
         histtype='step', linewidth=0.8, label='new Result')

plt.legend(loc='upper center', bbox_to_anchor=(0.75, 0.95), fontsize=10, markerscale=6, ncol=1, prop={'size': 7})
plt.xlim(0, 11)
plt.ylim(0, 1200)
plt.xlabel('#opWvf', labelpad=2, fontsize=8)
plt.ylabel('#Counts', labelpad=1, fontsize=8)
plt.tick_params(labelsize=7)
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)

plt.show()
# Out:
# previous (#wvf >= 5):  2922 (54.72%)
# new  (#wvf >= 5):  2929 (54.85%)
#
# Bin-by-bin comparison:
# Bin 0: Previous: 514; New: 512; Difference: -2
# Bin 1: Previous: 951; New: 937; Difference: -14
# Bin 2: Previous: 454; New: 457; Difference: 3
# Bin 3: Previous: 637; New: 633; Difference: -4
# Bin 4: Previous: 730; New: 728; Difference: -2
# Bin 5: Previous: 820; New: 807; Difference: -13
# Bin 6: Previous: 405; New: 393; Difference: -12
# Bin 7: Previous: 301; New: 269; Difference: -32
# Bin 8: Previous: 672; New: 603; Difference: -69
# Bin 9: Previous: 724; New: 857; Difference: 133
# Bin 10: Previous: 0; New: 0; Difference: 0

# %% [markdown]
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
#
# ## PeakFinder (based on merged wvfCoin result):

# %%
peakFinder_muTime = []
peakFinder_miTime = []
peakFinder_miCoin = []

# Open the text file and process each line
with open('./statResult/peakFinder_muonTime.txt', "r") as file:
    for line in file:
        line = line.strip()  # Remove any leading/trailing whitespace
        if not line:  # Skip empty lines
            continue
        # Each line is expected to be in the format: <filepath>: <number>
        parts = line.split(":")
        if len(parts) >= 2:
            try:
                # Convert the part after the colon to an integer and add to the list
                number = int(parts[1].strip())
                peakFinder_muTime.append(number)
            except ValueError:
                print(f"Could not convert {parts[1].strip()} to an integer.")

with open('./statResult/peakFinder_michelTime.txt', "r") as file:
    for line in file:
        line = line.strip()  # Remove any leading/trailing whitespace
        if not line:  # Skip empty lines
            continue
        # Each line is expected to be in the format: <filepath>: <number>
        parts = line.split(":")
        if len(parts) >= 2:
            try:
                # Convert the part after the colon to an integer and add to the list
                number = int(parts[1].strip())
                peakFinder_miTime.append(number)
            except ValueError:
                print(f"Could not convert {parts[1].strip()} to an integer.")

with open('./statResult/peakFinder_michelCoincidence.txt', "r") as file:
    for line in file:
        line = line.strip()  # Remove any leading/trailing whitespace
        if not line:  # Skip empty lines
            continue
        # Each line is expected to be in the format: <filepath>: <number>
        parts = line.split(":")
        if len(parts) >= 2:
            try:
                # Convert the part after the colon to an integer and add to the list
                number = int(parts[1].strip())
                peakFinder_miCoin.append(number)
            except ValueError:
                print(f"Could not convert {parts[1].strip()} to an integer.")



#Previous michel coincidence-------------------------------------------------
peakFinder_miCoinPre = []
with open('./statResult/peakFinder_michelCoincidencePrevious.txt', "r") as file:
    for line in file:
        line = line.strip()  # Remove any leading/trailing whitespace
        if not line:  # Skip empty lines
            continue
        # Each line is expected to be in the format: <filepath>: <number>
        parts = line.split(":")
        if len(parts) >= 2:
            try:
                # Convert the part after the colon to an integer and add to the list
                number = int(parts[1].strip())
                peakFinder_miCoinPre.append(number)
            except ValueError:
                print(f"Could not convert {parts[1].strip()} to an integer.")




#Muon lifetime---
# Element-wise subtraction: (mi - mu) for each corresponding element
mu_lifetime = [mi - mu for mi, mu in zip(peakFinder_miTime, peakFinder_muTime)]






print("Length of peakFinder_muTime:", len(peakFinder_muTime))
print("Length of peakFinder_miTime:", len(peakFinder_miTime))
print("Length of peakFinder_miCoin:", len(peakFinder_miCoin))
print("\nLength of mu_lifetime: ", len(mu_lifetime))

print("\nLength of peakFinder_miCoin (Previous):", len(peakFinder_miCoinPre))
# Out:
# Length of peakFinder_muTime: 2929
# Length of peakFinder_miTime: 2929
# Length of peakFinder_miCoin: 2929
#
# Length of mu_lifetime:  2929
#
# Length of peakFinder_miCoin (Previous): 2922

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit



#Initial Mu and Michel time distributions-------------------------------------------
plt.figure(figsize=(4,3),dpi=400)

# Plot histograms on the same canvas
plt.hist(peakFinder_muTime, bins=128, alpha=0.6, label='Muon Time')
plt.hist(peakFinder_miTime, bins=128, alpha=0.6, label='Michel Time')

plt.xlabel('Tick')
plt.ylabel('Counts')
plt.yscale('log')
#plt.title('Histogram of muTime and miTime')

plt.legend(loc='upper center', bbox_to_anchor=(0.7, 0.99), fontsize=9, markerscale=4, ncol=1, prop={'size':6})
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)

plt.show()








# Muon Lifetime distribution (INITIAL; NO fitting)--------------------------------------------
plt.figure(figsize=(4, 3), dpi=400)

# Convert to ns (assuming mu_lifetime is already defined)
mu_lifetime_ns = [value * 16 for value in mu_lifetime]
print("\nLifetime distribution:")
print("# Initial Candidates [-16000, 16000]: ", len(mu_lifetime_ns))

# Apply test cut
mu_lifetime_ns_test = [val for val in mu_lifetime_ns if 0 < val < 16000]
print("# Initial Candidates [0, 16000]: ", len(mu_lifetime_ns_test), "({:.2f}%)".format(len(mu_lifetime_ns_test)/len(mu_lifetime_ns)*100))

# Define histogram parameters
bin_width = 500
range_min = -16000
range_max = 16000
bins = np.arange(range_min, range_max + bin_width, bin_width)

# Plot histogram-----------------
plt.hist(mu_lifetime_ns, bins=bins, range=(range_min, range_max),
         edgecolor='blue', histtype='step', linewidth=0.8,
         label='Muon Lifetime')

plt.xlim(-16000, 16000)
plt.xlabel('Time [ns]', fontsize=8)
plt.ylabel('#Counts', fontsize=8)
plt.tick_params(labelsize=7)
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)
plt.legend(loc='upper center', bbox_to_anchor=(0.78, 0.95), fontsize=11, markerscale=5, ncol=1, prop={'size':8})
plt.show()









# Michel coincidence distribution------------------------------------------
plt.figure(figsize=(4,3),dpi=400)

#Define the range and bin width
bin_width = 1
range_min = 0
range_max = 11
bins = np.arange(range_min, range_max + bin_width, bin_width)

plt.plot([3, 3], [0, 1200], color="magenta", linewidth=1.5, linestyle='--')

plt.hist(peakFinder_miCoin, bins=bins, range=(range_min, range_max), edgecolor='blue', 
         histtype='step', linewidth=0.8, label='Michel Candidates Coincidence')

plt.legend(loc='upper center', bbox_to_anchor=(0.7, 0.99), fontsize=9, markerscale=5, ncol=1, prop={'size': 6})

plt.xlim(0, 11)
plt.ylim(0, 1200)
plt.xlabel('#opPeak', labelpad=2, fontsize=8)
plt.ylabel('#Counts', labelpad=1, fontsize=8)
#plt.ylim(0.1, 1000)
#plt.yscale('log')
plt.tick_params(labelsize=7)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)

plt.show() 







# Michel coincidence distribution (Compare with old one)---------------------------------
plt.figure(figsize=(4, 3), dpi=400)

bin_width = 1
range_min = 0
range_max = 11
bins = np.arange(range_min, range_max + bin_width, bin_width)

# Calculate histogram values
hist_current, _ = np.histogram(peakFinder_miCoin, bins=bins, range=(range_min, range_max))
hist_previous, _ = np.histogram(peakFinder_miCoinPre, bins=bins, range=(range_min, range_max))
bin_centers = (bins[:-1] + bins[1:]) / 2

# Print bin-by-bin comparison
print("\nBin-by-bin Michel Coincidence Comparison:")
for i, center in enumerate(bin_centers):
    diff = hist_current[i] - hist_previous[i]
    print(f"Bin {int(center)}: Current = {hist_current[i]}; Previous = {hist_previous[i]}; Difference = {diff}")

# Plotting------------------------------------------
# Vertical threshold line
plt.plot([3, 3], [0, max(max(hist_current), max(hist_previous), 1) + 50], color="magenta", linewidth=1.5, linestyle='--')

# Plot current results
plt.hist(peakFinder_miCoin, bins=bins, range=(range_min, range_max),
         edgecolor='green', histtype='step', linewidth=0.8, label='Michel Coincidence (Current)')

# Plot previous results
plt.hist(peakFinder_miCoinPre, bins=bins, range=(range_min, range_max),
         edgecolor='blue', histtype='step', linewidth=0.8, label='Michel Coincidence (Previous)')

# Final touches
plt.legend(loc='upper center', bbox_to_anchor=(0.7, 0.99), fontsize=9, markerscale=5, ncol=1, prop={'size': 6})
plt.xlim(0, 11)
plt.ylim(0, max(max(hist_current), max(hist_previous), 1) + 50)
plt.xlabel('#opPeak', labelpad=2, fontsize=8)
plt.ylabel('#Counts', labelpad=1, fontsize=8)
plt.tick_params(labelsize=7)
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)

plt.show()








#Lifetime vs opWvf (Original)===============================================

plt.figure(figsize=(4,3),dpi=400)

#y=x---
plt.plot([0, 10], [-16000, 16000], color="silver", linewidth=0.3, linestyle='--')
plt.plot([0, 10], [0, 0], color="red", linewidth=0.6, linestyle='-')


# Create a custom colormap where zero-frequency regions are white
plasma = plt.cm.plasma.copy()
plasma.set_under('white')  # Sets zero values to white

# Create a 2D histogram
hist, xedges, yedges, img = plt.hist2d(peakFinder_miCoin, mu_lifetime_ns, bins=(10, 160), range=[[0, 10], [-16000, 16000]],
                                       cmap=plasma, cmin=1)  # cmin=1 ensures zero bins remain white

# Add color bar
cbar = plt.colorbar()
cbar.set_label('Counts', fontsize=6)
cbar.ax.tick_params(labelsize=5)

# Labels and styling
plt.xlim(0, 10)
plt.ylim(-16000, 16000)
plt.xlabel('#opWvf', labelpad=1, fontsize=6)
plt.ylabel('Lifetime', labelpad=1, fontsize=6)
#plt.title('After Space Cut', fontsize=7)
plt.tick_params(labelsize=5)
# Out:
# Lifetime distribution:
# # Initial Candidates [-16000, 16000]:  2929
# # Initial Candidates [0, 16000]:  2761 (94.26%)
# Bin-by-bin Michel Coincidence Comparison:
# Bin 0: Current = 0; Previous = 0; Difference = 0
# Bin 1: Current = 140; Previous = 140; Difference = 0
# Bin 2: Current = 925; Previous = 930; Difference = -5
# Bin 3: Current = 862; Previous = 877; Difference = -15
# Bin 4: Current = 450; Previous = 438; Difference = 12
# Bin 5: Current = 222; Previous = 215; Difference = 7
# Bin 6: Current = 120; Previous = 128; Difference = -8
# Bin 7: Current = 94; Previous = 83; Difference = 11
# Bin 8: Current = 74; Previous = 75; Difference = -1
# Bin 9: Current = 42; Previous = 36; Difference = 6
# Bin 10: Current = 0; Previous = 0; Difference = 0

# %%
#Remove candidates with coincidence <3-----------------------------------------------
mu_lifetime_ns_purified = []

for i in range(0, len(peakFinder_miCoin)):
    coin = peakFinder_miCoin[i]
    time = mu_lifetime_ns[i]

    if coin >= 3:
        mu_lifetime_ns_purified.append(time)
    
print("Keep #coincidence >=3:")    
print("# Purified Candidates [-16000, 16000]: ", len(mu_lifetime_ns_purified))

#Test-------
mu_lifetime_ns_purified_00 = [val for val in mu_lifetime_ns_purified if 0 <= val <= 16000]
mu_lifetime_ns_purified_500 = [val for val in mu_lifetime_ns_purified if 500 <= val <= 16000]
print("# Purified Candidates [0, 16000]: ", len(mu_lifetime_ns_purified_00))
print("# Purified Candidates [500, 16000]: ", len(mu_lifetime_ns_purified_500))






# Muon Lifetime distribution (NO fitting)--------------------------------------------
plt.figure(figsize=(4, 3), dpi=400)

# Define histogram parameters
bin_width = 500
range_min = 500
range_max = 16000
bins = np.arange(range_min, range_max + bin_width, bin_width)

# Plot histogram-----------------
plt.hist(mu_lifetime_ns_purified_00, bins=bins, range=(range_min, range_max),
         edgecolor='blue', histtype='step', linewidth=0.8,
         label='Muon Lifetime')

plt.xlim(0, 16000)
plt.ylim(0, 400)
plt.xlabel('Time [ns]', fontsize=8)
plt.ylabel('#Counts', fontsize=8)
plt.tick_params(labelsize=7)
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)
plt.legend(loc='upper center', bbox_to_anchor=(0.78, 0.95), fontsize=11, markerscale=5, ncol=1, prop={'size':8})
plt.show()







#Plot---------------------------------------------------------------------------
plt.figure(figsize=(4, 3), dpi=400)

print("\nLeast Square Fitting:==================")

# Define histogram parameters
bin_width = 500
range_min = 500
range_max = 15500
bins = np.arange(range_min, range_max + bin_width, bin_width)

# Create the histogram and capture counts, bin edges, etc.
n, bin_edges, patches = plt.hist(mu_lifetime_ns_purified_500, bins=bins, range=(range_min, range_max),
                                 edgecolor='blue', histtype='step', linewidth=0.8,
                                 label='Muon Lifetime Preliminary')

# Calculate bin centers
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

# Calculate statistical uncertainties (sqrt(n))
yerr = np.sqrt(n)
yerr_plot = np.where(n == 0, 1, yerr)  # Avoid zero division error for empty bins

# Plot error bars on the histogram
plt.errorbar(bin_centers, n, yerr=yerr, fmt='o', color='blue', markersize=2)

# Define the exponential fitting function: N(t) = N0 * exp(-t/tau0) + C
def exp_func(t, N0, tau0, C):
    return N0 * np.exp(-t / tau0) + C

# Least Squares Method------
popt, pcov = curve_fit(exp_func, bin_centers, n, p0=[max(n), 1000, 1], sigma=yerr, absolute_sigma=True)
perr = np.sqrt(np.diag(pcov))  # parameter uncertainties

# Print entries and uncertainties for each bin
print("\nBin information:")
for i in range(len(n)):
    print(f"Bin {i+1}: Range = [{bin_edges[i]:.0f}, {bin_edges[i+1]:.0f}) | "
          f"Center = {bin_centers[i]:.0f} ns | "
          f"Entries = {n[i]:.0f} ± {yerr[i]:.1f}")

# Print results to terminal
print("\nFitted parameters:")
print("N0 = {:.2f} +/- {:.2f}".format(popt[0], perr[0]))
print("tau0 = {:.2f} +/- {:.2f} ns".format(popt[1], perr[1]))
print("C = {:.2f} +/- {:.2f}".format(popt[2], perr[2]))

# Calculate chi-squared
expected = exp_func(bin_centers, *popt)
expected = np.clip(expected, 1e-10, None)  # Avoid division by zero
residuals = n - expected
chi2 = np.sum((residuals / yerr_plot) ** 2)
ndf = len(n) - len(popt)
chi2_ndf = chi2 / ndf

# Print goodness-of-fit summary
print(f"\n[Goodness of Fit] χ² / ndf = {chi2:.1f} / {ndf} = {chi2_ndf:.2f}")

# Print detailed bin-by-bin information
for i, (label, observed, exp_val, res, err) in enumerate(zip(bin_centers, n, expected, residuals, yerr_plot)):
    print(f"Bin {i} (center={label:.2f}): n = {observed:.2f}; expected = {exp_val:.2f}; "
          f"residual = {res:.2f}; residual / yerr = {res / err:.2f}")

# Plot and legend----------
n0_text = f'N₀ = {popt[0]:.0f} ± {perr[0]:.0f}'
tau_text = f'τ = {popt[1]:.0f} ± {perr[1]:.0f} ns'
c_text = f'C = {popt[2]:.1f} ± {perr[2]:.1f}'
chi2_text = f'χ² / ndf = {chi2:.1f} / {ndf}'

t_fit = np.linspace(range_min, range_max, 1000)
fit_line, = plt.plot(t_fit, exp_func(t_fit, *popt), color='red', linestyle='--', label=tau_text)

# Dummy handles for text-only legend entries
dummy_n0 = plt.Line2D([], [], color='none', label=n0_text)
dummy_c = plt.Line2D([], [], color='none', label=c_text)
dummy_chi2 = plt.Line2D([], [], color='none', label=chi2_text)

# Histogram handle
hist_handle = plt.Line2D([], [], color='blue', linestyle='-', label='Muon Lifetime Preliminary')

plt.legend(handles=[hist_handle, fit_line, dummy_n0, dummy_c, dummy_chi2],
           loc='upper center', bbox_to_anchor=(0.7, 0.99),
           fontsize=7, ncol=1, prop={'size': 6})

plt.xlim(0, 16000)
plt.ylim(0.9, 400)
#plt.yscale('log')
plt.xlabel('Time [ns]', labelpad=2, fontsize=8)
plt.ylabel('#Counts', labelpad=1, fontsize=8)
plt.tick_params(labelsize=7)
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)
plt.show()
# Out:
# Keep #coincidence >=3:
# # Purified Candidates [-16000, 16000]:  1864
# # Purified Candidates [0, 16000]:  1755
# # Purified Candidates [500, 16000]:  1673
# Least Square Fitting:==================
#
# Bin information:
# Bin 1: Range = [500, 1000) | Center = 750 ns | Entries = 320 ± 17.9
# Bin 2: Range = [1000, 1500) | Center = 1250 ns | Entries = 276 ± 16.6
# Bin 3: Range = [1500, 2000) | Center = 1750 ns | Entries = 201 ± 14.2
# Bin 4: Range = [2000, 2500) | Center = 2250 ns | Entries = 172 ± 13.1
# Bin 5: Range = [2500, 3000) | Center = 2750 ns | Entries = 119 ± 10.9
# Bin 6: Range = [3000, 3500) | Center = 3250 ns | Entries = 103 ± 10.1
# Bin 7: Range = [3500, 4000) | Center = 3750 ns | Entries = 72 ± 8.5
# Bin 8: Range = [4000, 4500) | Center = 4250 ns | Entries = 70 ± 8.4
# Bin 9: Range = [4500, 5000) | Center = 4750 ns | Entries = 54 ± 7.3
# Bin 10: Range = [5000, 5500) | Center = 5250 ns | Entries = 31 ± 5.6
# Bin 11: Range = [5500, 6000) | Center = 5750 ns | Entries = 38 ± 6.2
# Bin 12: Range = [6000, 6500) | Center = 6250 ns | Entries = 25 ± 5.0
# Bin 13: Range = [6500, 7000) | Center = 6750 ns | Entries = 18 ± 4.2
# Bin 14: Range = [7000, 7500) | Center = 7250 ns | Entries = 17 ± 4.1
# Bin 15: Range = [7500, 8000) | Center = 7750 ns | Entries = 10 ± 3.2
# Bin 16: Range = [8000, 8500) | Center = 8250 ns | Entries = 10 ± 3.2
# Bin 17: Range = [8500, 9000) | Center = 8750 ns | Entries = 17 ± 4.1
# Bin 18: Range = [9000, 9500) | Center = 9250 ns | Entries = 10 ± 3.2
# Bin 19: Range = [9500, 10000) | Center = 9750 ns | Entries = 11 ± 3.3
# Bin 20: Range = [10000, 10500) | Center = 10250 ns | Entries = 8 ± 2.8
# Bin 21: Range = [10500, 11000) | Center = 10750 ns | Entries = 9 ± 3.0
# Bin 22: Range = [11000, 11500) | Center = 11250 ns | Entries = 12 ± 3.5
# Bin 23: Range = [11500, 12000) | Center = 11750 ns | Entries = 8 ± 2.8
# Bin 24: Range = [12000, 12500) | Center = 12250 ns | Entries = 11 ± 3.3
# Bin 25: Range = [12500, 13000) | Center = 12750 ns | Entries = 8 ± 2.8
# Bin 26: Range = [13000, 13500) | Center = 13250 ns | Entries = 9 ± 3.0
# Bin 27: Range = [13500, 14000) | Center = 13750 ns | Entries = 8 ± 2.8
# Bin 28: Range = [14000, 14500) | Center = 14250 ns | Entries = 10 ± 3.2
# Bin 29: Range = [14500, 15000) | Center = 14750 ns | Entries = 9 ± 3.0
# Bin 30: Range = [15000, 15500) | Center = 15250 ns | Entries = 7 ± 2.6
#
# Fitted parameters:
# N0 = 497.01 +/- 24.41
# tau0 = 1882.41 +/- 74.17 ns
# C = 7.48 +/- 0.89
#
# [Goodness of Fit] χ² / ndf = 18.7 / 27 = 0.69
# Bin 0 (center=750.00): n = 320.00; expected = 341.16; residual = -21.16; residual / yerr = -1.18
# Bin 1 (center=1250.00): n = 276.00; expected = 263.32; residual = 12.68; residual / yerr = 0.76
# Bin 2 (center=1750.00): n = 201.00; expected = 203.64; residual = -2.64; residual / yerr = -0.19
# Bin 3 (center=2250.00): n = 172.00; expected = 157.88; residual = 14.12; residual / yerr = 1.08
# Bin 4 (center=2750.00): n = 119.00; expected = 122.80; residual = -3.80; residual / yerr = -0.35
# Bin 5 (center=3250.00): n = 103.00; expected = 95.90; residual = 7.10; residual / yerr = 0.70
# Bin 6 (center=3750.00): n = 72.00; expected = 75.27; residual = -3.27; residual / yerr = -0.39
# Bin 7 (center=4250.00): n = 70.00; expected = 59.46; residual = 10.54; residual / yerr = 1.26
# Bin 8 (center=4750.00): n = 54.00; expected = 47.33; residual = 6.67; residual / yerr = 0.91
# Bin 9 (center=5250.00): n = 31.00; expected = 38.03; residual = -7.03; residual / yerr = -1.26
# Bin 10 (center=5750.00): n = 38.00; expected = 30.91; residual = 7.09; residual / yerr = 1.15
# Bin 11 (center=6250.00): n = 25.00; expected = 25.44; residual = -0.44; residual / yerr = -0.09
# Bin 12 (center=6750.00): n = 18.00; expected = 21.25; residual = -3.25; residual / yerr = -0.77
# Bin 13 (center=7250.00): n = 17.00; expected = 18.04; residual = -1.04; residual / yerr = -0.25
# Bin 14 (center=7750.00): n = 10.00; expected = 15.57; residual = -5.57; residual / yerr = -1.76
# Bin 15 (center=8250.00): n = 10.00; expected = 13.68; residual = -3.68; residual / yerr = -1.17
# Bin 16 (center=8750.00): n = 17.00; expected = 12.24; residual = 4.76; residual / yerr = 1.16
# Bin 17 (center=9250.00): n = 10.00; expected = 11.13; residual = -1.13; residual / yerr = -0.36
# Bin 18 (center=9750.00): n = 11.00; expected = 10.27; residual = 0.73; residual / yerr = 0.22
# Bin 19 (center=10250.00): n = 8.00; expected = 9.62; residual = -1.62; residual / yerr = -0.57
# Bin 20 (center=10750.00): n = 9.00; expected = 9.12; residual = -0.12; residual / yerr = -0.04
# Bin 21 (center=11250.00): n = 12.00; expected = 8.74; residual = 3.26; residual / yerr = 0.94
# Bin 22 (center=11750.00): n = 8.00; expected = 8.44; residual = -0.44; residual / yerr = -0.16
# Bin 23 (center=12250.00): n = 11.00; expected = 8.22; residual = 2.78; residual / yerr = 0.84
# Bin 24 (center=12750.00): n = 8.00; expected = 8.04; residual = -0.04; residual / yerr = -0.02
# Bin 25 (center=13250.00): n = 9.00; expected = 7.91; residual = 1.09; residual / yerr = 0.36
# Bin 26 (center=13750.00): n = 8.00; expected = 7.81; residual = 0.19; residual / yerr = 0.07
# Bin 27 (center=14250.00): n = 10.00; expected = 7.73; residual = 2.27; residual / yerr = 0.72
# Bin 28 (center=14750.00): n = 9.00; expected = 7.67; residual = 1.33; residual / yerr = 0.44
# Bin 29 (center=15250.00): n = 7.00; expected = 7.63; residual = -0.63; residual / yerr = -0.24

# %% [markdown]
# <br />
# <br />
#
# #### Maximum Likelihood Estimation:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
from scipy.special import gammaln
import numdifftools as nd  # For estimating the Hessian matrix
from scipy.stats import chi2 as chi2_dist

# Your histogram data: replace this with your actual data
# mu_lifetime_ns_purified_test = ...

# Plot setup
plt.figure(figsize=(4, 3), dpi=400)

print("\nMaximum Likelihood Estimation:==================")

# Histogram parameters
bin_width = 500
range_min = 500
range_max = 15500
bins = np.arange(range_min, range_max + bin_width, bin_width)

# Create histogram
n, bin_edges, patches = plt.hist(mu_lifetime_ns_purified_500, bins=bins, range=(range_min, range_max),
                                 edgecolor='blue', histtype='step', linewidth=0.8,
                                 label='Muon Lifetime Preliminary')

# Bin centers
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

# Plot error bars assuming Poisson errors
yerr = np.sqrt(n)
yerr_plot = np.where(n == 0, 1, yerr)
plt.errorbar(bin_centers, n, yerr=yerr_plot, fmt='o', color='blue', markersize=2)

# Exponential function to fit
def exp_func(t, N0, tau0, C):
    return N0 * np.exp(-t / tau0) + C

# Negative log-likelihood function for Poisson statistics
def neg_log_likelihood(params, t, counts):
    N0, tau0, C = params
    mu = exp_func(t, N0, tau0, C)
    mu = np.clip(mu, 1e-10, None)  # prevent log(0) and negative values
    log_likelihood = np.sum(counts * np.log(mu) - mu - gammaln(counts + 1))
    return -log_likelihood

# Initial guess for parameters
initial_guess = [max(n), 1000, 1]

# Minimize negative log-likelihood
result = minimize(neg_log_likelihood, initial_guess, args=(bin_centers, n), method='L-BFGS-B')

# Extract fit parameters and uncertainties
if result.success:
    popt = result.x
    print("\n[MLE Fit] Fitted parameters (Poisson likelihood):")
    print("N0 = {:.2f}".format(popt[0]))
    print("tau0 = {:.2f} ns".format(popt[1]))
    print("C = {:.2f}".format(popt[2]))

    # Estimate uncertainties via Hessian
    hessian_fun = nd.Hessian(lambda params: neg_log_likelihood(params, bin_centers, n))
    hessian = hessian_fun(popt)
    pcov = np.linalg.inv(hessian)
    perr = np.sqrt(np.diag(pcov))
    print("\n[MLE Fit] Parameter uncertainties:")
    print("N0 uncertainty = {:.2f}".format(perr[0]))
    print("tau0 uncertainty = {:.2f} ns".format(perr[1]))
    print("C uncertainty = {:.2f}".format(perr[2]))

    # Text for legend
    n0_text = f'N₀ = {popt[0]:.0f} ± {perr[0]:.0f}'
    tau_text = f'τ = {popt[1]:.0f} ± {perr[1]:.0f} ns'
    c_text = f'C = {popt[2]:.1f} ± {perr[2]:.1f}'

    # Plot fitted curve
    t_fit = np.linspace(range_min, range_max, 1000)
    fit_line, = plt.plot(t_fit, exp_func(t_fit, *popt), color='red', linestyle='--', label=tau_text)

    # Calculate residuals and chi^2/ndf for visual goodness-of-fit check
    expected = exp_func(bin_centers, *popt)
    expected = np.clip(expected, 1e-10, None)
    residuals = n - expected
    chi2 = np.sum((residuals / yerr_plot) ** 2)
    ndf = len(n) - len(popt)
    chi2_ndf = chi2 / ndf

    print(f"\n[Goodness of Fit] χ² / ndf = {chi2:.1f} / {ndf} = {chi2_ndf:.2f}")

    for i, (label, observed, exp_val, res, err) in enumerate(zip(bin_centers, n, expected, residuals, yerr_plot)):
        print(f"Bin {i} (center={label:.2f}): n = {observed:.2f}; expected = {exp_val:.2f}; residual = {res:.2f}; residual/yerr = {res / err:.2f}")



    # -------------------------------
    # Evaluate goodness-of-fit via Likelihood Ratio Test
    # -------------------------------

    # Log-likelihood for the fitted model:
    mu_fit = exp_func(bin_centers, *popt)
    mu_fit = np.clip(mu_fit, 1e-10, None)
    logL_model = np.sum(n * np.log(mu_fit) - mu_fit - gammaln(n + 1))

    # For the saturated model, we use the observed counts (treating 0*log(0) as 0).
    def safe_nlogn(n_val):
        return np.where(n_val > 0, n_val * np.log(n_val), 0)

    logL_sat = np.sum(safe_nlogn(n) - n - gammaln(n + 1))

    # Compute the likelihood ratio statistic (deviance):
    G2 = 2 * (logL_sat - logL_model)
    print(f"\n[MLE Fit] Likelihood Ratio Test Statistic (G²): {G2:.2f}")

    # Degrees of freedom (number of bins - number of parameters)
    dof = len(n) - len(popt)
    print(f"Degrees of Freedom: {dof}")

    # Calculate p-value based on chi-squared distribution
    p_value = chi2_dist.sf(G2, dof)
    print(f"P-value: {p_value:.4f}")

    # Dummy handles for legend
    dummy_n0 = plt.Line2D([], [], color='none', label=n0_text)
    dummy_c = plt.Line2D([], [], color='none', label=c_text)
    dummy_pval = plt.Line2D([], [], color='none', label=f'p-value = {p_value:.3f}')

    # Histogram handle
    hist_handle = plt.Line2D([], [], color='blue', linestyle='-', label='Muon Lifetime Preliminary')

    # Plot legend
    plt.legend(handles=[hist_handle, fit_line, dummy_n0, dummy_c, dummy_pval],
               loc='upper center', bbox_to_anchor=(0.7, 0.99),
               fontsize=7, ncol=1, prop={'size': 6})

else:
    print("❌ Fit failed:", result.message)

# Final plot formatting
plt.xlim(0, 16000)
plt.ylim(0.9, 400)
plt.yscale('log')
plt.xlabel('Time [ns]', labelpad=2, fontsize=8)
plt.ylabel('#Counts', labelpad=1, fontsize=8)
plt.tick_params(labelsize=7)
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)
plt.show()

# Print entries and uncertainties for each bin
print("\nBin information:")
for i in range(len(n)):
    print(f"Bin {i+1}: Range = [{bin_edges[i]:.0f}, {bin_edges[i+1]:.0f}) | "
          f"Center = {bin_centers[i]:.0f} ns | "
          f"Entries = {n[i]:.0f} ± {yerr[i]:.1f}")
# Out:
# Maximum Likelihood Estimation:==================
#
# [MLE Fit] Fitted parameters (Poisson likelihood):
# N0 = 492.98
# tau0 = 1904.68 ns
# C = 7.78
#
# [MLE Fit] Parameter uncertainties:
# N0 uncertainty = 24.19
# tau0 uncertainty = 73.47 ns
# C uncertainty = 0.86
#
# [Goodness of Fit] χ² / ndf = 19.3 / 27 = 0.72
# Bin 0 (center=750.00): n = 320.00; expected = 340.30; residual = -20.30; residual/yerr = -1.13
# Bin 1 (center=1250.00): n = 276.00; expected = 263.53; residual = 12.47; residual/yerr = 0.75
# Bin 2 (center=1750.00): n = 201.00; expected = 204.48; residual = -3.48; residual/yerr = -0.25
# Bin 3 (center=2250.00): n = 172.00; expected = 159.06; residual = 12.94; residual/yerr = 0.99
# Bin 4 (center=2750.00): n = 119.00; expected = 124.13; residual = -5.13; residual/yerr = -0.47
# Bin 5 (center=3250.00): n = 103.00; expected = 97.27; residual = 5.73; residual/yerr = 0.56
# Bin 6 (center=3750.00): n = 72.00; expected = 76.61; residual = -4.61; residual/yerr = -0.54
# Bin 7 (center=4250.00): n = 70.00; expected = 60.72; residual = 9.28; residual/yerr = 1.11
# Bin 8 (center=4750.00): n = 54.00; expected = 48.49; residual = 5.51; residual/yerr = 0.75
# Bin 9 (center=5250.00): n = 31.00; expected = 39.09; residual = -8.09; residual/yerr = -1.45
# Bin 10 (center=5750.00): n = 38.00; expected = 31.86; residual = 6.14; residual/yerr = 1.00
# Bin 11 (center=6250.00): n = 25.00; expected = 26.30; residual = -1.30; residual/yerr = -0.26
# Bin 12 (center=6750.00): n = 18.00; expected = 22.02; residual = -4.02; residual/yerr = -0.95
# Bin 13 (center=7250.00): n = 17.00; expected = 18.74; residual = -1.74; residual/yerr = -0.42
# Bin 14 (center=7750.00): n = 10.00; expected = 16.21; residual = -6.21; residual/yerr = -1.96
# Bin 15 (center=8250.00): n = 10.00; expected = 14.26; residual = -4.26; residual/yerr = -1.35
# Bin 16 (center=8750.00): n = 17.00; expected = 12.76; residual = 4.24; residual/yerr = 1.03
# Bin 17 (center=9250.00): n = 10.00; expected = 11.61; residual = -1.61; residual/yerr = -0.51
# Bin 18 (center=9750.00): n = 11.00; expected = 10.73; residual = 0.27; residual/yerr = 0.08
# Bin 19 (center=10250.00): n = 8.00; expected = 10.05; residual = -2.05; residual/yerr = -0.72
# Bin 20 (center=10750.00): n = 9.00; expected = 9.52; residual = -0.52; residual/yerr = -0.17
# Bin 21 (center=11250.00): n = 12.00; expected = 9.12; residual = 2.88; residual/yerr = 0.83
# Bin 22 (center=11750.00): n = 8.00; expected = 8.81; residual = -0.81; residual/yerr = -0.29
# Bin 23 (center=12250.00): n = 11.00; expected = 8.57; residual = 2.43; residual/yerr = 0.73
# Bin 24 (center=12750.00): n = 8.00; expected = 8.39; residual = -0.39; residual/yerr = -0.14
# Bin 25 (center=13250.00): n = 9.00; expected = 8.25; residual = 0.75; residual/yerr = 0.25
# Bin 26 (center=13750.00): n = 8.00; expected = 8.14; residual = -0.14; residual/yerr = -0.05
# Bin 27 (center=14250.00): n = 10.00; expected = 8.06; residual = 1.94; residual/yerr = 0.62
# Bin 28 (center=14750.00): n = 9.00; expected = 7.99; residual = 1.01; residual/yerr = 0.34
# Bin 29 (center=15250.00): n = 7.00; expected = 7.94; residual = -0.94; residual/yerr = -0.36
#
# [MLE Fit] Likelihood Ratio Test Statistic (G²): 18.09
# Degrees of Freedom: 27
# P-value: 0.9009
# Bin information:
# Bin 1: Range = [500, 1000) | Center = 750 ns | Entries = 320 ± 17.9
# Bin 2: Range = [1000, 1500) | Center = 1250 ns | Entries = 276 ± 16.6
# Bin 3: Range = [1500, 2000) | Center = 1750 ns | Entries = 201 ± 14.2
# Bin 4: Range = [2000, 2500) | Center = 2250 ns | Entries = 172 ± 13.1
# Bin 5: Range = [2500, 3000) | Center = 2750 ns | Entries = 119 ± 10.9
# Bin 6: Range = [3000, 3500) | Center = 3250 ns | Entries = 103 ± 10.1
# Bin 7: Range = [3500, 4000) | Center = 3750 ns | Entries = 72 ± 8.5
# Bin 8: Range = [4000, 4500) | Center = 4250 ns | Entries = 70 ± 8.4
# Bin 9: Range = [4500, 5000) | Center = 4750 ns | Entries = 54 ± 7.3
# Bin 10: Range = [5000, 5500) | Center = 5250 ns | Entries = 31 ± 5.6
# Bin 11: Range = [5500, 6000) | Center = 5750 ns | Entries = 38 ± 6.2
# Bin 12: Range = [6000, 6500) | Center = 6250 ns | Entries = 25 ± 5.0
# Bin 13: Range = [6500, 7000) | Center = 6750 ns | Entries = 18 ± 4.2
# Bin 14: Range = [7000, 7500) | Center = 7250 ns | Entries = 17 ± 4.1
# Bin 15: Range = [7500, 8000) | Center = 7750 ns | Entries = 10 ± 3.2
# Bin 16: Range = [8000, 8500) | Center = 8250 ns | Entries = 10 ± 3.2
# Bin 17: Range = [8500, 9000) | Center = 8750 ns | Entries = 17 ± 4.1
# Bin 18: Range = [9000, 9500) | Center = 9250 ns | Entries = 10 ± 3.2
# Bin 19: Range = [9500, 10000) | Center = 9750 ns | Entries = 11 ± 3.3
# Bin 20: Range = [10000, 10500) | Center = 10250 ns | Entries = 8 ± 2.8
# Bin 21: Range = [10500, 11000) | Center = 10750 ns | Entries = 9 ± 3.0
# Bin 22: Range = [11000, 11500) | Center = 11250 ns | Entries = 12 ± 3.5
# Bin 23: Range = [11500, 12000) | Center = 11750 ns | Entries = 8 ± 2.8
# Bin 24: Range = [12000, 12500) | Center = 12250 ns | Entries = 11 ± 3.3
# Bin 25: Range = [12500, 13000) | Center = 12750 ns | Entries = 8 ± 2.8
# Bin 26: Range = [13000, 13500) | Center = 13250 ns | Entries = 9 ± 3.0
# Bin 27: Range = [13500, 14000) | Center = 13750 ns | Entries = 8 ± 2.8
# Bin 28: Range = [14000, 14500) | Center = 14250 ns | Entries = 10 ± 3.2
# Bin 29: Range = [14500, 15000) | Center = 14750 ns | Entries = 9 ± 3.0
# Bin 30: Range = [15000, 15500) | Center = 15250 ns | Entries = 7 ± 2.6

# %% [markdown]
# <br />
# <br />
#
# #### Fitting with double exponential function:
#
# $$
# \large
# N(t) = N_1 \cdot e^{-t / \tau_1} + N_2 \cdot e^{-t / \tau_2} + C
# $$
# where $\tau_2 = 2200 ns$

# %%
#Remove candidates with coincidence <3-----------------------------------------------
mu_lifetime_ns_purified = []

for i in range(0, len(peakFinder_miCoin)):
    coin = peakFinder_miCoin[i]
    time = mu_lifetime_ns[i]

    if coin >= 3:
        mu_lifetime_ns_purified.append(time)
    
print("Keep #coincidence >=3:")    
print("# Purified Candidates [-16000, 16000]: ", len(mu_lifetime_ns_purified))

#Test-------
mu_lifetime_ns_purified_00 = [val for val in mu_lifetime_ns_purified if 0 <= val <= 16000]
mu_lifetime_ns_purified_500 = [val for val in mu_lifetime_ns_purified if 0 <= val <= 16000]
print("# Purified Candidates [0, 16000]: ", len(mu_lifetime_ns_purified_00))
print("# Purified Candidates [500, 16000]: ", len(mu_lifetime_ns_purified_500))









#Plot---------------------------------------------------------------------------
plt.figure(figsize=(4, 3), dpi=400)

print("\nLeast Square Fitting:==================")

# Define histogram parameters
bin_width = 500
range_min = 500
range_max = 15500
bins = np.arange(range_min, range_max + bin_width, bin_width)

# Create the histogram and capture counts, bin edges, etc.
n, bin_edges, patches = plt.hist(mu_lifetime_ns_purified_500, bins=bins, range=(range_min, range_max),
                                 edgecolor='blue', histtype='step', linewidth=0.8)

# Calculate bin centers
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

# Calculate statistical uncertainties (sqrt(n))
yerr = np.sqrt(n)
yerr_plot = np.where(n == 0, 1, yerr)  # Avoid zero division error for empty bins

# Plot error bars on the histogram
hist_handle = plt.errorbar(bin_centers, n, yerr=yerr, fmt='o', color='blue', markersize=2, label='Muon Lifetime Preliminary')

# Define the double exponential function with fixed tau_2 = 2200 ns
def exp_func_fixed_tau2(t, N1, tau1, N2, C):
    tau2_fixed = 2200  # ns
    return N1 * np.exp(-t / tau1) + N2 * np.exp(-t / tau2_fixed) + C

# Least Squares Method with fixed tau_2-------
# Initial guess: [N1, tau1, N2, C]
popt, pcov = curve_fit(
    exp_func_fixed_tau2, bin_centers, n,
    p0=[max(n)/5, 500, max(n), 10],
    sigma=yerr, absolute_sigma=True,
    maxfev=10000  # increased from default 1000
)
perr = np.sqrt(np.diag(pcov))  # parameter uncertainties

# Print entries and uncertainties for each bin
print("\nBin information:")
for i in range(len(n)):
    print(f"Bin {i+1}: Range = [{bin_edges[i]:.0f}, {bin_edges[i+1]:.0f}) | "
          f"Center = {bin_centers[i]:.0f} ns | "
          f"Entries = {n[i]:.0f} ± {yerr[i]:.1f}")

# Print fitted parameters
print("\nFitted parameters:")
print("N1 = {:.2f} +/- {:.2f}".format(popt[0], perr[0]))
print("tau1 = {:.2f} +/- {:.2f} ns".format(popt[1], perr[1]))
print("N2 = {:.2f} +/- {:.2f}".format(popt[2], perr[2]))
print("C = {:.2f} +/- {:.2f}".format(popt[3], perr[3]))

# Calculate expected values and chi-squared
expected = exp_func_fixed_tau2(bin_centers, *popt)
expected = np.clip(expected, 1e-10, None)
residuals = n - expected
chi2 = np.sum((residuals / yerr_plot) ** 2)
ndf = len(n) - len(popt)
chi2_ndf = chi2 / ndf

print(f"\n[Goodness of Fit] χ² / ndf = {chi2:.1f} / {ndf} = {chi2_ndf:.2f}")

# Print detailed bin-by-bin information
for i, (label, observed, exp_val, res, err) in enumerate(zip(bin_centers, n, expected, residuals, yerr_plot)):
    print(f"Bin {i} (center={label:.2f}): n = {observed:.2f}; expected = {exp_val:.2f}; "
          f"residual = {res:.2f}; residual / yerr = {res / err:.2f}")

# Plot and legend----------
n1_text = f'N₁ = {popt[0]:.0f} ± {perr[0]:.0f}'
tau1_text = f'τ₁ = {popt[1]:.0f} ± {perr[1]:.0f} ns'
n2_text = f'N₂ = {popt[2]:.0f} ± {perr[2]:.0f}'
c_text = f'C = {popt[3]:.1f} ± {perr[3]:.1f}'
chi2_text = f'χ² / ndf = {chi2:.1f} / {ndf}'

t_fit = np.linspace(range_min, range_max, 1000)
fit_line, = plt.plot(t_fit, exp_func_fixed_tau2(t_fit, *popt), color='red', linestyle='--', label=tau1_text)

# Dummy handles for displaying additional info in the legend
dummy_n1 = plt.Line2D([], [], color='none', label=n1_text)
dummy_n2 = plt.Line2D([], [], color='none', label=n2_text)
dummy_c = plt.Line2D([], [], color='none', label=c_text)
dummy_chi2 = plt.Line2D([], [], color='none', label=chi2_text)

# Finalize legend
plt.legend(handles=[hist_handle, fit_line, dummy_n1, dummy_n2, dummy_c, dummy_chi2],
           loc='upper center', bbox_to_anchor=(0.7, 0.99),
           fontsize=7, ncol=1, prop={'size': 6})

plt.xlim(0, 16000)
plt.ylim(0.9, 400)
plt.yscale('log')
plt.xlabel('Time [ns]', labelpad=2, fontsize=8)
plt.ylabel('#Counts', labelpad=1, fontsize=8)
plt.tick_params(labelsize=7)
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)
plt.show()
# Out:
# Keep #coincidence >=3:
# # Purified Candidates [-16000, 16000]:  1864
# # Purified Candidates [0, 16000]:  1755
# # Purified Candidates [500, 16000]:  1755
#
# Least Square Fitting:==================
#
# Bin information:
# Bin 1: Range = [500, 1000) | Center = 750 ns | Entries = 320 ± 17.9
# Bin 2: Range = [1000, 1500) | Center = 1250 ns | Entries = 276 ± 16.6
# Bin 3: Range = [1500, 2000) | Center = 1750 ns | Entries = 201 ± 14.2
# Bin 4: Range = [2000, 2500) | Center = 2250 ns | Entries = 172 ± 13.1
# Bin 5: Range = [2500, 3000) | Center = 2750 ns | Entries = 119 ± 10.9
# Bin 6: Range = [3000, 3500) | Center = 3250 ns | Entries = 103 ± 10.1
# Bin 7: Range = [3500, 4000) | Center = 3750 ns | Entries = 72 ± 8.5
# Bin 8: Range = [4000, 4500) | Center = 4250 ns | Entries = 70 ± 8.4
# Bin 9: Range = [4500, 5000) | Center = 4750 ns | Entries = 54 ± 7.3
# Bin 10: Range = [5000, 5500) | Center = 5250 ns | Entries = 31 ± 5.6
# Bin 11: Range = [5500, 6000) | Center = 5750 ns | Entries = 38 ± 6.2
# Bin 12: Range = [6000, 6500) | Center = 6250 ns | Entries = 25 ± 5.0
# Bin 13: Range = [6500, 7000) | Center = 6750 ns | Entries = 18 ± 4.2
# Bin 14: Range = [7000, 7500) | Center = 7250 ns | Entries = 17 ± 4.1
# Bin 15: Range = [7500, 8000) | Center = 7750 ns | Entries = 10 ± 3.2
# Bin 16: Range = [8000, 8500) | Center = 8250 ns | Entries = 10 ± 3.2
# Bin 17: Range = [8500, 9000) | Center = 8750 ns | Entries = 17 ± 4.1
# Bin 18: Range = [9000, 9500) | Center = 9250 ns | Entries = 10 ± 3.2
# Bin 19: Range = [9500, 10000) | Center = 9750 ns | Entries = 11 ± 3.3
# Bin 20: Range = [10000, 10500) | Center = 10250 ns | Entries = 8 ± 2.8
# Bin 21: Range = [10500, 11000) | Center = 10750 ns | Entries = 9 ± 3.0
# Bin 22: Range = [11000, 11500) | Center = 11250 ns | Entries = 12 ± 3.5
# Bin 23: Range = [11500, 12000) | Center = 11750 ns | Entries = 8 ± 2.8
# Bin 24: Range = [12000, 12500) | Center = 12250 ns | Entries = 11 ± 3.3
# Bin 25: Range = [12500, 13000) | Center = 12750 ns | Entries = 8 ± 2.8
# Bin 26: Range = [13000, 13500) | Center = 13250 ns | Entries = 9 ± 3.0
# Bin 27: Range = [13500, 14000) | Center = 13750 ns | Entries = 8 ± 2.8
# Bin 28: Range = [14000, 14500) | Center = 14250 ns | Entries = 10 ± 3.2
# Bin 29: Range = [14500, 15000) | Center = 14750 ns | Entries = 9 ± 3.0
# Bin 30: Range = [15000, 15500) | Center = 15250 ns | Entries = 7 ± 2.6
#
# Fitted parameters:
# N1 = 622925.82 +/- 1481580142.16
# tau1 = 2199.75 +/- 603.16 ns
# N2 = -622433.04 +/- 1481580161.88
# C = 8.03 +/- 1.10
#
# [Goodness of Fit] χ² / ndf = 17.5 / 26 = 0.67
# Bin 0 (center=750.00): n = 320.00; expected = 341.04; residual = -21.04; residual / yerr = -1.18
# Bin 1 (center=1250.00): n = 276.00; expected = 264.09; residual = 11.91; residual / yerr = 0.72
# Bin 2 (center=1750.00): n = 201.00; expected = 204.67; residual = -3.67; residual / yerr = -0.26
# Bin 3 (center=2250.00): n = 172.00; expected = 158.83; residual = 13.17; residual / yerr = 1.00
# Bin 4 (center=2750.00): n = 119.00; expected = 123.49; residual = -4.49; residual / yerr = -0.41
# Bin 5 (center=3250.00): n = 103.00; expected = 96.29; residual = 6.71; residual / yerr = 0.66
# Bin 6 (center=3750.00): n = 72.00; expected = 75.38; residual = -3.38; residual / yerr = -0.40
# Bin 7 (center=4250.00): n = 70.00; expected = 59.33; residual = 10.67; residual / yerr = 1.28
# Bin 8 (center=4750.00): n = 54.00; expected = 47.01; residual = 6.99; residual / yerr = 0.95
# Bin 9 (center=5250.00): n = 31.00; expected = 37.59; residual = -6.59; residual / yerr = -1.18
# Bin 10 (center=5750.00): n = 38.00; expected = 30.38; residual = 7.62; residual / yerr = 1.24
# Bin 11 (center=6250.00): n = 25.00; expected = 24.88; residual = 0.12; residual / yerr = 0.02
# Bin 12 (center=6750.00): n = 18.00; expected = 20.70; residual = -2.70; residual / yerr = -0.64
# Bin 13 (center=7250.00): n = 17.00; expected = 17.52; residual = -0.52; residual / yerr = -0.13
# Bin 14 (center=7750.00): n = 10.00; expected = 15.11; residual = -5.11; residual / yerr = -1.61
# Bin 15 (center=8250.00): n = 10.00; expected = 13.28; residual = -3.28; residual / yerr = -1.04
# Bin 16 (center=8750.00): n = 17.00; expected = 11.91; residual = 5.09; residual / yerr = 1.23
# Bin 17 (center=9250.00): n = 10.00; expected = 10.88; residual = -0.88; residual / yerr = -0.28
# Bin 18 (center=9750.00): n = 11.00; expected = 10.10; residual = 0.90; residual / yerr = 0.27
# Bin 19 (center=10250.00): n = 8.00; expected = 9.53; residual = -1.53; residual / yerr = -0.54
# Bin 20 (center=10750.00): n = 9.00; expected = 9.10; residual = -0.10; residual / yerr = -0.03
# Bin 21 (center=11250.00): n = 12.00; expected = 8.78; residual = 3.22; residual / yerr = 0.93
# Bin 22 (center=11750.00): n = 8.00; expected = 8.55; residual = -0.55; residual / yerr = -0.19
# Bin 23 (center=12250.00): n = 11.00; expected = 8.38; residual = 2.62; residual / yerr = 0.79
# Bin 24 (center=12750.00): n = 8.00; expected = 8.26; residual = -0.26; residual / yerr = -0.09
# Bin 25 (center=13250.00): n = 9.00; expected = 8.17; residual = 0.83; residual / yerr = 0.28
# Bin 26 (center=13750.00): n = 8.00; expected = 8.11; residual = -0.11; residual / yerr = -0.04
# Bin 27 (center=14250.00): n = 10.00; expected = 8.07; residual = 1.93; residual / yerr = 0.61
# Bin 28 (center=14750.00): n = 9.00; expected = 8.04; residual = 0.96; residual / yerr = 0.32
# Bin 29 (center=15250.00): n = 7.00; expected = 8.02; residual = -1.02; residual / yerr = -0.39
