# %% [markdown]
# # Statistics for Michel electron candidate (pdsp run005809)
#
# ### Created by Shu, 20250728---

# %% [markdown]
# #### To explore decay points distribution asymmetry along drift direction

# %% [markdown]
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
#
# ## Initial Candidates (MS>0.001):

# %%
decayX_ini = []#Candidates initial---
decayY_ini = []
decayZ_ini = []

startX_ini = []#Candidates initial---
startY_ini = []
startZ_ini = []

ms_ini = []#Michel score initial---
mh_ini = []

pandoraT0_ini = []


with open('./statResult/decayX_initial.txt', 'r') as filehandle:
    for line in filehandle:
        currentPlace = line[:-1]
        decayX_ini.append(float(currentPlace))
with open('./statResult/decayY_initial.txt', 'r') as filehandle:
    for line in filehandle:
        currentPlace = line[:-1]
        decayY_ini.append(float(currentPlace))
with open('./statResult/decayZ_initial.txt', 'r') as filehandle:
    for line in filehandle:
        currentPlace = line[:-1]
        decayZ_ini.append(float(currentPlace))

with open('./statResult/startX_initial.txt', 'r') as filehandle:
    for line in filehandle:
        currentPlace = line[:-1]
        startX_ini.append(float(currentPlace))
with open('./statResult/startY_initial.txt', 'r') as filehandle:
    for line in filehandle:
        currentPlace = line[:-1]
        startY_ini.append(float(currentPlace))
with open('./statResult/startZ_initial.txt', 'r') as filehandle:
    for line in filehandle:
        currentPlace = line[:-1]
        startZ_ini.append(float(currentPlace))

with open('./statResult/michelScore_initial.txt', 'r') as filehandle:
    for line in filehandle:
        currentPlace = line[:-1]
        ms_ini.append(float(currentPlace))
with open('./statResult/michelHits_initial.txt', 'r') as filehandle:
    for line in filehandle:
        currentPlace = line[:-1]
        mh_ini.append(float(currentPlace))

with open('./statResult/pandoraT0.txt', 'r') as filehandle:
    for line in filehandle:
        currentPlace = line[:-1]
        pandoraT0_ini.append(float(currentPlace))


print("Candidates initial: decayX: ", len(decayX_ini))
print("Candidates initial: decayY: ", len(decayY_ini))
print("Candidates initial: decayZ: ", len(decayZ_ini))

print("Candidates initial: startX: ", len(startX_ini))
print("Candidates initial: startY: ", len(startY_ini))
print("Candidates initial: startZ: ", len(startZ_ini))

print("Candidates initial: Michel score: ", len(ms_ini))
print("Candidates initial: Michel hit  : ", len(mh_ini))

print("Candidates initial: Pandora T0  : ", len(pandoraT0_ini))
# Out:
# Candidates initial: decayX:  276706
# Candidates initial: decayY:  276706
# Candidates initial: decayZ:  276706
# Candidates initial: startX:  276706
# Candidates initial: startY:  276706
# Candidates initial: startZ:  276706
# Candidates initial: Michel score:  276706
# Candidates initial: Michel hit  :  276706
# Candidates initial: Pandora T0  :  276706

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

#Start drawing figures======================================    
#Set the limts of x, y and z when drawing---
xmin = -450
xmax = 450
ymin = -100
ymax = 700
zmin = -100
zmax = 800

#Field cage range---
cageMinX = -360
cageMaxX = 360
cageMinY = 0
cageMaxY = 605
cageMinZ = 0
cageMaxZ = 695





#Decay points distribution:==========================================

print("Decay points distribution: ")


# Plotting the histogram (X distribution)---------------
plt.figure(figsize=(4,3),dpi=400)

#APA planes---
plt.plot([-360, -360], [0, 15000], color="blue", linewidth=0.8, linestyle='--')
plt.plot([360, 360], [0, 15000], color="blue", linewidth=0.8, linestyle='--')

#Define the range and bin width
bin_width = 10
range_min = -400
range_max = 400
bins = np.arange(range_min, range_max + bin_width, bin_width)

plt.hist(decayX_ini, bins=bins, range=(range_min, range_max), edgecolor='magenta', 
         histtype='step', linewidth=0.8)


plt.xlim(-450, 450)
plt.xlabel(r'$x_1$ [cm]', labelpad=2, fontsize=8)
plt.ylabel('#Counts', labelpad=1, fontsize=8)
plt.gca().invert_xaxis()  # Flip x-axis
plt.ylim(0.1, 15000)
#plt.yscale('log')
plt.tick_params(labelsize=7)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)

plt.show()  



#Z-X plane ploting (Top View)----------------------------------------
plt.figure(figsize=(4,3),dpi=400)

#auxiliary line, along y(geo) and x axis---
aux2 = [-360, 360, 360, -360, -360] #y shoud be x---
aux1 = [695, 695, 0, 0, 695]
plt.plot(aux1, aux2, color="blue", linewidth=0.8, linestyle='-')

#Drawing of data points------
plt.scatter(decayZ_ini, decayX_ini, c='magenta', s=2.0, alpha=1.0, marker='.', label='Magenta Bias')

plt.axis('scaled')
plt.xlim(zmin, zmax)#z---
plt.ylim(xmin, xmax)
plt.ylabel('X axis [cm]', labelpad=1, fontsize=5)
plt.xlabel('Z axis [cm]', labelpad=1, fontsize=5)
plt.tick_params(labelsize=4)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.3, zorder=0)
plt.show()



#Y-X plane ploting (Front View)----------------------------------------
plt.figure(figsize=(4,3),dpi=400)

#auxiliary line, along y(geo) and x axis---
aux2 = [0, 605, 605, 0, 0] #y shoud be y---
aux1 = [360, 360, -360, -360, 360]
plt.plot(aux1, aux2, color="blue", linewidth=0.8, linestyle='-')

#Drawing of data points------
plt.scatter(decayX_ini, decayY_ini, c='magenta', s=2.0, alpha=1.0, marker='.', label='Magenta Bias')

plt.axis('scaled')
plt.xlim(xmin, xmax)#z---
plt.ylim(ymin, ymax)
plt.gca().invert_xaxis()  # Flip x-axis
plt.xlabel('X axis [cm]', labelpad=1, fontsize=5)
plt.ylabel('Y axis [cm]', labelpad=1, fontsize=5)
plt.tick_params(labelsize=4)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.3, zorder=0)
plt.show() 



#Y-Z plane ploting (Side View)----------------------------------------
plt.figure(figsize=(4,3),dpi=400)

#auxiliary line, along y(geo) and x axis---
aux2 = [0, 605, 605, 0, 0] #y shoud be y---
aux1 = [695, 695, 0, 0, 695]
plt.plot(aux1, aux2, color="blue", linewidth=0.8, linestyle='-')

#Drawing of data points------
plt.scatter(decayZ_ini, decayY_ini, c='magenta', s=2.0, alpha=1.0, marker='.', label='Magenta Bias')

plt.axis('scaled')
plt.xlim(zmin, zmax)#z---
plt.ylim(ymin, ymax)
#plt.gca().invert_xaxis()  # Flip x-axis
plt.xlabel('Z axis [cm]', labelpad=1, fontsize=5)
plt.ylabel('Y axis [cm]', labelpad=1, fontsize=5)
plt.tick_params(labelsize=4)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.3, zorder=0)
plt.show() 






#Starting points distribution:==========================================

print("\n\n\nStarting points distribution: ")


# Plotting the histogram (X distribution)---------------
plt.figure(figsize=(4,3),dpi=400)

#APA planes---
plt.plot([-360, -360], [0, 5000], color="blue", linewidth=0.8, linestyle='--')
plt.plot([360, 360], [0, 5000], color="blue", linewidth=0.8, linestyle='--')

#Define the range and bin width
bin_width = 10
range_min = -400
range_max = 400
bins = np.arange(range_min, range_max + bin_width, bin_width)

plt.hist(startX_ini, bins=bins, range=(range_min, range_max), edgecolor='magenta', 
         histtype='step', linewidth=0.8)


plt.xlim(-450, 450)
plt.xlabel(r'$x_1$ [cm]', labelpad=2, fontsize=8)
plt.ylabel('#Counts', labelpad=1, fontsize=8)
plt.gca().invert_xaxis()  # Flip x-axis
plt.ylim(0.1, 5000)
#plt.yscale('log')
plt.tick_params(labelsize=7)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)

plt.show()  



#Z-X plane ploting (Top View)----------------------------------------
plt.figure(figsize=(4,3),dpi=400)

#auxiliary line, along y(geo) and x axis---
aux2 = [-360, 360, 360, -360, -360] #y shoud be x---
aux1 = [695, 695, 0, 0, 695]
plt.plot(aux1, aux2, color="blue", linewidth=0.8, linestyle='-')

#Drawing of data points------
plt.scatter(startZ_ini, startX_ini, c='magenta', s=2.0, alpha=1.0, marker='.', label='Magenta Bias')

plt.axis('scaled')
plt.xlim(zmin, zmax)#z---
plt.ylim(xmin, xmax)
plt.ylabel('X axis [cm]', labelpad=1, fontsize=5)
plt.xlabel('Z axis [cm]', labelpad=1, fontsize=5)
plt.tick_params(labelsize=4)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.3, zorder=0)
plt.show()



#Y-X plane ploting (Front View)----------------------------------------
plt.figure(figsize=(4,3),dpi=400)

#auxiliary line, along y(geo) and x axis---
aux2 = [0, 605, 605, 0, 0] #y shoud be y---
aux1 = [360, 360, -360, -360, 360]
plt.plot(aux1, aux2, color="blue", linewidth=0.8, linestyle='-')

#Drawing of data points------
plt.scatter(startX_ini, startY_ini, c='magenta', s=2.0, alpha=1.0, marker='.', label='Magenta Bias')

plt.axis('scaled')
plt.xlim(xmin, xmax)#z---
plt.ylim(ymin, ymax)
plt.gca().invert_xaxis()  # Flip x-axis
plt.xlabel('X axis [cm]', labelpad=1, fontsize=5)
plt.ylabel('Y axis [cm]', labelpad=1, fontsize=5)
plt.tick_params(labelsize=4)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.3, zorder=0)
plt.show() 



#Y-Z plane ploting (Side View)----------------------------------------
plt.figure(figsize=(4,3),dpi=400)

#auxiliary line, along y(geo) and x axis---
aux2 = [0, 605, 605, 0, 0] #y shoud be y---
aux1 = [695, 695, 0, 0, 695]
plt.plot(aux1, aux2, color="blue", linewidth=0.8, linestyle='-')

#Drawing of data points------
plt.scatter(startZ_ini, startY_ini, c='magenta', s=2.0, alpha=1.0, marker='.', label='Magenta Bias')

plt.axis('scaled')
plt.xlim(zmin, zmax)#z---
plt.ylim(ymin, ymax)
#plt.gca().invert_xaxis()  # Flip x-axis
plt.xlabel('Z axis [cm]', labelpad=1, fontsize=5)
plt.ylabel('Y axis [cm]', labelpad=1, fontsize=5)
plt.tick_params(labelsize=4)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.3, zorder=0)
plt.show() 





#Decay points distribution:==========================================

print("Pandora T0 Distribution: ")


# Plotting the histogram (X distribution)---------------
plt.figure(figsize=(4,3),dpi=400)

#plt.plot([-360, -360], [0, 10000], color="blue", linewidth=0.8, linestyle='--')
#plt.plot([360, 360], [0, 10000], color="blue", linewidth=0.8, linestyle='--')

#Define the range and bin width
bin_width = 0.1
range_min = -4
range_max = 4
bins = np.arange(range_min, range_max + bin_width, bin_width)

plt.hist(pandoraT0_ini, bins=bins, range=(range_min, range_max), edgecolor='magenta', 
         histtype='step', linewidth=0.8)


plt.xlim(-4, 4)
plt.xlabel('pandora T0 [ms]', labelpad=2, fontsize=8)
plt.ylabel('#Counts', labelpad=1, fontsize=8)
#plt.gca().invert_xaxis()  # Flip x-axis
plt.ylim(0.1, 20000)
#plt.yscale('log')
plt.tick_params(labelsize=7)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)

plt.show()
# Out:
# Decay points distribution:
# Starting points distribution:
# Pandora T0 Distribution:

# %%
#Michel score distribution (Original)----------------------------------------
plt.figure(figsize=(4,3),dpi=400)

#Define the range and bin width
bin_width = 0.01
range_min = 0
range_max = 1.00
bins = np.arange(range_min, range_max + bin_width, bin_width)

plt.hist(ms_ini, bins=bins, range=(range_min, range_max), edgecolor='magenta', 
         histtype='step', linewidth=0.8)


plt.xlim(-0.02, 1.02)
plt.xlabel('Michel Score', labelpad=2, fontsize=8)
plt.ylabel('#Counts', labelpad=1, fontsize=8)
plt.ylim(0, 60000)
#plt.yscale('log')
plt.tick_params(labelsize=7)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)

plt.show()  







#Michel hits distribution (Original)-----------------------------------------
plt.figure(figsize=(4,3),dpi=400)

#Define the range and bin width
bin_width = 1
range_min = 0
range_max = 100
bins = np.arange(range_min, range_max + bin_width, bin_width)

plt.hist(mh_ini, bins=bins, range=(range_min, range_max), edgecolor='magenta', 
         histtype='step', linewidth=0.8)


plt.xlim(-1, 101)
plt.xlabel('Michel Hits', labelpad=2, fontsize=8)
plt.ylabel('#Counts', labelpad=1, fontsize=8)
plt.ylim(0,60000)
#plt.yscale('log')
plt.tick_params(labelsize=7)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)

plt.show()  






#Michel Score vs Michel Hits==========================================================
plt.figure(figsize=(4,3),dpi=400)

#y=x---
plt.plot([0, 80], [0, 1], color="silver", linewidth=0.3, linestyle='--')
plt.plot([0, 80], [0.4, 0.4], color="blue", linewidth=0.6, linestyle='-')
plt.plot([5, 5], [0, 1], color="blue", linewidth=0.6, linestyle='-')


# Create a custom colormap where zero-frequency regions are white
plasma = plt.cm.plasma.copy()
plasma.set_under('white')  # Sets zero values to white

# Create a 2D histogram
hist, xedges, yedges, img = plt.hist2d(mh_ini, ms_ini, bins=(80, 80), range=[[0, 80], [0, 1]],
                                       cmap=plasma, cmin=1)  # cmin=1 ensures zero bins remain white

# Add color bar
cbar = plt.colorbar()
cbar.set_label('Counts', fontsize=6)
cbar.ax.tick_params(labelsize=5)

# Labels and styling
plt.xlim(0, 80)
plt.ylim(0, 1)
plt.xlabel('Michel Hits', labelpad=1, fontsize=6)
plt.ylabel('Michel Score', labelpad=1, fontsize=6)
plt.title('MS vs MH', fontsize=7)
plt.tick_params(labelsize=5)

# %% [markdown]
# <br />
# <br />
# <br />
# <br />
# <br />
#
# ## Apply Cuts:

# %%
decayX_TPC = []#Candidates after TPC cuts---
decayY_TPC = []
decayZ_TPC = []

startX_TPC = []#Candidates initial---
startY_TPC = []
startZ_TPC = []

ms_TPC = []#Michel score initial---
mh_TPC = []

pandoraT0_TPC = []



for i in range(0, len(decayX_ini)):
    x_decay = decayX_ini[i]
    y_decay = decayY_ini[i]
    z_decay = decayZ_ini[i]    
    x_start = startX_ini[i]
    y_start = startY_ini[i]
    z_start = startZ_ini[i]  
    ms = ms_ini[i]
    mh = mh_ini[i]
    t0 = pandoraT0_ini[i]

    #Default region: 0<y<605, 0<z<695 (SPACE CUT)---
    if -360 < x_decay < 360 and 30 < y_decay < 580 and 30 < z_decay < 670:    
        if 0.4 < ms: #(Michel score cut)---
            if 5 < mh: #Michel hits cut---  
                if t0 < -0.1 or t0 > 0.1:
                    decayX_TPC.append(x_decay)
                    decayY_TPC.append(y_decay)
                    decayZ_TPC.append(z_decay)
                    startX_TPC.append(x_start)
                    startY_TPC.append(y_start)
                    startZ_TPC.append(z_start)      
                    ms_TPC.append(ms)
                    mh_TPC.append(mh)
                    pandoraT0_TPC.append(t0)

print("\nSize of X (TPC cuts) : ", len(decayX_TPC), "({:.3f}%)".format(len(decayX_TPC)/len(decayX_ini)*100))
print("decayX_TPC: ", len(decayX_TPC))
print("decayY_TPC: ", len(decayY_TPC))
print("decayZ_TPC: ", len(decayZ_TPC))

print("startX_TPC: ", len(startX_TPC))
print("startY_TPC: ", len(startY_TPC))
print("startZ_TPC: ", len(startZ_TPC))

print("Michel score _TPC: ", len(ms_TPC))
print("Michel hit   _TPC: ", len(mh_TPC))

print("pandoraT0_TPC: ", len(pandoraT0_TPC))
# Out:
# Size of X (TPC cuts) :  32790 (11.850%)
# decayX_TPC:  32790
# decayY_TPC:  32790
# decayZ_TPC:  32790
# startX_TPC:  32790
# startY_TPC:  32790
# startZ_TPC:  32790
# Michel score _TPC:  32790
# Michel hit   _TPC:  32790
# pandoraT0_TPC:  32790

# %%
#Decay points distribution:==========================================

print("Decay points distribution: ")



decayX_TPC = np.array(decayX_TPC)
neg_X = np.sum(decayX_TPC < 0)
pos_X = np.sum(decayX_TPC >= 0)
print("\n# of X < 0 : ", neg_X, "({:.3f}%)".format(neg_X/len(decayX_TPC)*100))
print("# of X >= 0: ", pos_X, "({:.3f}%)".format(pos_X/len(decayX_TPC)*100))

# Plotting the histogram (X distribution)---------------
plt.figure(figsize=(4,3),dpi=400)

#APA planes---
plt.plot([-360, -360], [0, 2500], color="blue", linewidth=0.8, linestyle='--')
plt.plot([360, 360], [0, 2500], color="blue", linewidth=0.8, linestyle='--')

#Define the range and bin width
bin_width = 10
range_min = -400
range_max = 400
bins = np.arange(range_min, range_max + bin_width, bin_width)

plt.hist(decayX_TPC, bins=bins, range=(range_min, range_max), edgecolor='magenta', 
         histtype='step', linewidth=0.8)


plt.xlim(-450, 450)
plt.xlabel(r'$x_1$ [cm]', labelpad=2, fontsize=8)
plt.ylabel('#Counts', labelpad=1, fontsize=8)
plt.gca().invert_xaxis()  # Flip x-axis
plt.ylim(0.1, 2500)
#plt.yscale('log')
plt.tick_params(labelsize=7)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)

plt.show()  



#Z-X plane ploting (Top View)----------------------------------------
plt.figure(figsize=(4,3),dpi=400)

#auxiliary line, along y(geo) and x axis---
aux2 = [-360, 360, 360, -360, -360] #y shoud be x---
aux1 = [695, 695, 0, 0, 695]
plt.plot(aux1, aux2, color="blue", linewidth=0.8, linestyle='-')

# Create a custom colormap where zero-frequency regions are white
plasma = plt.cm.plasma.copy()
plasma.set_under('white')  # Sets zero values to white

# Create a 2D histogram
hist, xedges, yedges, img = plt.hist2d(decayZ_TPC, decayX_TPC, bins=(120, 120), range=[[zmin, zmax], [xmin, xmax]],
                                       cmap=plasma, cmin=1)  # cmin=1 ensures zero bins remain white

# Add color bar
cbar = plt.colorbar()
cbar.set_label('Counts', fontsize=6)
cbar.ax.tick_params(labelsize=5)

plt.axis('scaled')
plt.xlim(zmin, zmax)#z---
plt.ylim(xmin, xmax)
plt.ylabel('X axis [cm]', labelpad=1, fontsize=5)
plt.xlabel('Z axis [cm]', labelpad=1, fontsize=5)
plt.title('Top View', fontsize=7)
plt.tick_params(labelsize=4)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.3, zorder=0)
plt.show()





#Y-X plane ploting (Front View)----------------------------------------
plt.figure(figsize=(4,3),dpi=400)

#auxiliary line, along y(geo) and x axis---
aux2 = [0, 605, 605, 0, 0] #y shoud be y---
aux1 = [360, 360, -360, -360, 360]
plt.plot(aux1, aux2, color="blue", linewidth=0.8, linestyle='-')


# Create a custom colormap where zero-frequency regions are white
plasma = plt.cm.plasma.copy()
plasma.set_under('white')  # Sets zero values to white

# Create a 2D histogram
hist, xedges, yedges, img = plt.hist2d(decayX_TPC, decayY_TPC, bins=(120, 120), range=[[xmin, xmax], [ymin, ymax]],
                                       cmap=plasma, cmin=1)  # cmin=1 ensures zero bins remain white

# Add color bar
cbar = plt.colorbar()
cbar.set_label('Counts', fontsize=6)
cbar.ax.tick_params(labelsize=5)


plt.axis('scaled')
plt.xlim(xmin, xmax)#z---
plt.ylim(ymin, ymax)
plt.gca().invert_xaxis()  # Flip x-axis
plt.xlabel('X axis [cm]', labelpad=1, fontsize=5)
plt.ylabel('Y axis [cm]', labelpad=1, fontsize=5)
plt.title('Front View', fontsize=7)
plt.tick_params(labelsize=4)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.3, zorder=0)
plt.show() 




#Y-Z plane ploting (Side View)----------------------------------------
plt.figure(figsize=(4,3),dpi=400)

#auxiliary line, along y(geo) and x axis---
aux2 = [0, 605, 605, 0, 0] #y shoud be y---
aux1 = [695, 695, 0, 0, 695]
plt.plot(aux1, aux2, color="blue", linewidth=0.8, linestyle='-')

# Create a custom colormap where zero-frequency regions are white
plasma = plt.cm.plasma.copy()
plasma.set_under('white')  # Sets zero values to white

# Create a 2D histogram
hist, xedges, yedges, img = plt.hist2d(decayZ_TPC, decayY_TPC, bins=(120, 120), range=[[zmin, zmax], [ymin, ymax]],
                                       cmap=plasma, cmin=1)  # cmin=1 ensures zero bins remain white

# Add color bar
cbar = plt.colorbar()
cbar.set_label('Counts', fontsize=6)
cbar.ax.tick_params(labelsize=5)


plt.axis('scaled')
plt.xlim(zmin, zmax)#z---
plt.ylim(ymin, ymax)
#plt.gca().invert_xaxis()  # Flip x-axis
plt.xlabel('Z axis [cm]', labelpad=1, fontsize=5)
plt.ylabel('Y axis [cm]', labelpad=1, fontsize=5)
plt.title('Side View', fontsize=7)
plt.tick_params(labelsize=4)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.3, zorder=0)
plt.show() 
















#Starting points distribution:==========================================

print("\n\n\nStarting points distribution: ")


# Plotting the histogram (X distribution)---------------
plt.figure(figsize=(4,3),dpi=400)

#APA planes---
plt.plot([-360, -360], [0, 2500], color="blue", linewidth=0.8, linestyle='--')
plt.plot([360, 360], [0, 2500], color="blue", linewidth=0.8, linestyle='--')

#Define the range and bin width
bin_width = 10
range_min = -400
range_max = 400
bins = np.arange(range_min, range_max + bin_width, bin_width)

plt.hist(startX_TPC, bins=bins, range=(range_min, range_max), edgecolor='magenta', 
         histtype='step', linewidth=0.8)


plt.xlim(-450, 450)
plt.xlabel(r'$x_1$ [cm]', labelpad=2, fontsize=8)
plt.ylabel('#Counts', labelpad=1, fontsize=8)
plt.gca().invert_xaxis()  # Flip x-axis
plt.ylim(0.1, 2500)
#plt.yscale('log')
plt.tick_params(labelsize=7)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)

plt.show()  





#Z-X plane ploting (Top View)----------------------------------------
plt.figure(figsize=(4,3),dpi=400)

#auxiliary line, along y(geo) and x axis---
aux2 = [-360, 360, 360, -360, -360] #y shoud be x---
aux1 = [695, 695, 0, 0, 695]
plt.plot(aux1, aux2, color="blue", linewidth=0.8, linestyle='-')

# Create a custom colormap where zero-frequency regions are white
plasma = plt.cm.plasma.copy()
plasma.set_under('white')  # Sets zero values to white

# Create a 2D histogram
hist, xedges, yedges, img = plt.hist2d(startZ_TPC, startX_TPC, bins=(120, 120), range=[[zmin, zmax], [xmin, xmax]],
                                       cmap=plasma, cmin=1)  # cmin=1 ensures zero bins remain white

# Add color bar
cbar = plt.colorbar()
cbar.set_label('Counts', fontsize=6)
cbar.ax.tick_params(labelsize=5)

plt.axis('scaled')
plt.xlim(zmin, zmax)#z---
plt.ylim(xmin, xmax)
plt.ylabel('X axis [cm]', labelpad=1, fontsize=5)
plt.xlabel('Z axis [cm]', labelpad=1, fontsize=5)
plt.title('Top View', fontsize=7)
plt.tick_params(labelsize=4)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.3, zorder=0)
plt.show()





#Y-X plane ploting (Front View)----------------------------------------
plt.figure(figsize=(4,3),dpi=400)

#auxiliary line, along y(geo) and x axis---
aux2 = [0, 605, 605, 0, 0] #y shoud be y---
aux1 = [360, 360, -360, -360, 360]
plt.plot(aux1, aux2, color="blue", linewidth=0.8, linestyle='-')


# Create a custom colormap where zero-frequency regions are white
plasma = plt.cm.plasma.copy()
plasma.set_under('white')  # Sets zero values to white

# Create a 2D histogram
hist, xedges, yedges, img = plt.hist2d(startX_TPC, startY_TPC, bins=(120, 120), range=[[xmin, xmax], [ymin, ymax]],
                                       cmap=plasma, cmin=1)  # cmin=1 ensures zero bins remain white

# Add color bar
cbar = plt.colorbar()
cbar.set_label('Counts', fontsize=6)
cbar.ax.tick_params(labelsize=5)


plt.axis('scaled')
plt.xlim(xmin, xmax)#z---
plt.ylim(ymin, ymax)
plt.gca().invert_xaxis()  # Flip x-axis
plt.xlabel('X axis [cm]', labelpad=1, fontsize=5)
plt.ylabel('Y axis [cm]', labelpad=1, fontsize=5)
plt.title('Front View', fontsize=7)
plt.tick_params(labelsize=4)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.3, zorder=0)
plt.show() 





#Y-Z plane ploting (Side View)----------------------------------------
plt.figure(figsize=(4,3),dpi=400)

#auxiliary line, along y(geo) and x axis---
aux2 = [0, 605, 605, 0, 0] #y shoud be y---
aux1 = [695, 695, 0, 0, 695]
plt.plot(aux1, aux2, color="blue", linewidth=0.8, linestyle='-')

# Create a custom colormap where zero-frequency regions are white
plasma = plt.cm.plasma.copy()
plasma.set_under('white')  # Sets zero values to white

# Create a 2D histogram
hist, xedges, yedges, img = plt.hist2d(startZ_TPC, startY_TPC, bins=(120, 120), range=[[zmin, zmax], [ymin, ymax]],
                                       cmap=plasma, cmin=1)  # cmin=1 ensures zero bins remain white

# Add color bar
cbar = plt.colorbar()
cbar.set_label('Counts', fontsize=6)
cbar.ax.tick_params(labelsize=5)


plt.axis('scaled')
plt.xlim(zmin, zmax)#z---
plt.ylim(ymin, ymax)
#plt.gca().invert_xaxis()  # Flip x-axis
plt.xlabel('Z axis [cm]', labelpad=1, fontsize=5)
plt.ylabel('Y axis [cm]', labelpad=1, fontsize=5)
plt.title('Side View', fontsize=7)
plt.tick_params(labelsize=4)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.3, zorder=0)
plt.show() 




#Decay points distribution:==========================================

print("Pandora T0 Distribution: ")


# Plotting the histogram (X distribution)---------------
plt.figure(figsize=(4,3),dpi=400)

#plt.plot([-360, -360], [0, 10000], color="blue", linewidth=0.8, linestyle='--')
#plt.plot([360, 360], [0, 10000], color="blue", linewidth=0.8, linestyle='--')

#Define the range and bin width
bin_width = 0.05
range_min = -4
range_max = 4
bins = np.arange(range_min, range_max + bin_width, bin_width)

plt.hist(pandoraT0_TPC, bins=bins, range=(range_min, range_max), edgecolor='magenta', 
         histtype='step', linewidth=0.8)


plt.xlim(-4, 4)
plt.xlabel('pandora T0 [ms]', labelpad=2, fontsize=8)
plt.ylabel('#Counts', labelpad=1, fontsize=8)
#plt.gca().invert_xaxis()  # Flip x-axis
plt.ylim(0.1, 1200)
#plt.yscale('log')
plt.tick_params(labelsize=7)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)

plt.show()
# Out:
# Decay points distribution:
#
# # of X < 0 :  17417 (53.117%)
# # of X >= 0:  15373 (46.883%)
# Starting points distribution:
# Pandora T0 Distribution:

# %% [markdown]
# ### Seperate decay points into four APA regions:

# %%
decayX_apa1 = []
decayX_apa2 = []
decayX_apa3 = []
decayX_apa4 = []

decayZ_apa1 = []
decayZ_apa2 = []
decayZ_apa3 = []
decayZ_apa4 = []

startX_apa1 = []
startX_apa2 = []
startX_apa3 = []
startX_apa4 = []

startZ_apa1 = []
startZ_apa2 = []
startZ_apa3 = []
startZ_apa4 = []



#Do seperation:
for i in range(0, len(decayZ_ini)):
    z = decayZ_ini[i]
    x = decayX_ini[i]
    start_x = startX_ini[i]
    start_z = startZ_ini[i]

    if x <= 0 and z <= 231.266: #APA1
        decayX_apa1.append(x)
        decayZ_apa1.append(z) 
        startX_apa1.append(start_x)
        startZ_apa1.append(start_z)               
    elif x <= 0 and z > 231.266: #APA2
        decayX_apa2.append(x)
        decayZ_apa2.append(z) 
        startX_apa2.append(start_x)
        startZ_apa2.append(start_z)        
    elif x > 0 and z <= 231.266: #APA3
        decayX_apa3.append(x)
        decayZ_apa3.append(z) 
        startX_apa3.append(start_x)
        startZ_apa3.append(start_z)
    elif x > 0 and z > 231.266: #APA4
        decayX_apa4.append(x)
        decayZ_apa4.append(z) 
        startX_apa4.append(start_x)
        startZ_apa4.append(start_z)



print("#decayX_ini (total): ", len(decayX_ini))
print("#decayX_apa1: ", len(decayX_apa1), "({:.2f}%)".format(len(decayX_apa1)/len(decayX_ini)*100))
print("#decayX_apa2: ", len(decayX_apa2), "({:.2f}%)".format(len(decayX_apa2)/len(decayX_ini)*100))
print("#decayX_apa3: ", len(decayX_apa3), "({:.2f}%)".format(len(decayX_apa3)/len(decayX_ini)*100))
print("#decayX_apa4: ", len(decayX_apa4), "({:.2f}%)".format(len(decayX_apa4)/len(decayX_ini)*100))




#Statistics:
#Starting points distribution:---------------
apa1_s = 0
apa2_s = 0
apa3_s = 0
apa4_s = 0
for i in range(0, len(startZ_ini)):
    x = startX_ini[i]
    z = startZ_ini[i]

    if x <= 0 and z <= 231.266: #APA1
        apa1_s += 1             
    elif x <= 0 and z > 231.266: #APA2
        apa2_s += 1       
    elif x > 0 and z <= 231.266: #APA3
        apa3_s += 1 
    elif x > 0 and z > 231.266: #APA4
        apa4_s += 1 
print("\n\n\n#startX_ini (total): ", len(decayX_ini))
print("#startX_apa1: ", apa1_s, "({:.2f}%)".format(apa1_s/len(decayX_ini)*100))
print("#startX_apa2: ", apa2_s, "({:.2f}%)".format(apa2_s/len(decayX_ini)*100))
print("#startX_apa3: ", apa3_s, "({:.2f}%)".format(apa3_s/len(decayX_ini)*100))
print("#startX_apa4: ", apa4_s, "({:.2f}%)".format(apa4_s/len(decayX_ini)*100))





#Starting points distribution of APA1:---------------
apa1_a1 = 0
apa2_a1 = 0
apa3_a1 = 0
apa4_a1 = 0
for i in range(0, len(decayX_apa4)):
    x = startX_apa4[i]
    z = startZ_apa4[i]

    if x <= 0 and z <= 231.266: #APA1
        apa1_a1 += 1             
    elif x <= 0 and z > 231.266: #APA2
        apa2_a1 += 1       
    elif x > 0 and z <= 231.266: #APA3
        apa3_a1 += 1 
    elif x > 0 and z > 231.266: #APA4
        apa4_a1 += 1 
print("\n\n\n#decayX_apa1 (total): ", len(decayX_apa4))
print("#startX_apa1: ", apa1_a1, "({:.2f}%)".format(apa1_a1/len(decayX_apa4)*100))
print("#startX_apa2: ", apa2_a1, "({:.2f}%)".format(apa2_a1/len(decayX_apa4)*100))
print("#startX_apa3: ", apa3_a1, "({:.2f}%)".format(apa3_a1/len(decayX_apa4)*100))
print("#startX_apa4: ", apa4_a1, "({:.2f}%)".format(apa4_a1/len(decayX_apa4)*100))
# Out:
# #decayX_TPC (total):  12757
# #decayX_apa1:  1399 (10.97%)
# #decayX_apa2:  8131 (63.74%)
# #decayX_apa3:  1465 (11.48%)
# #decayX_apa4:  1762 (13.81%)
#
#
#
# #startX_TPC (total):  12757
# #startX_apa1:  1126 (8.83%)
# #startX_apa2:  1887 (14.79%)
# #startX_apa3:  2949 (23.12%)
# #startX_apa4:  6795 (53.26%)
#
#
#
# #decayX_apa1 (total):  1762
# #startX_apa1:  381 (21.62%)
# #startX_apa2:  1209 (68.62%)
# #startX_apa3:  27 (1.53%)
# #startX_apa4:  145 (8.23%)

# %%
#Decay points distribution:==========================================

print("Decay points distribution: ")

#Z-X plane ploting (Top View)----------------------------------------
plt.figure(figsize=(4,3),dpi=400)

#auxiliary line, along y(geo) and x axis---
aux2 = [0, 465, 465, 0, 0] #y shoud be y---
aux1 = [356, 356, -356, -356, 356]
plt.plot(aux2, aux1, color="blue", linewidth=0.8, linestyle='-')

#Drawing of data points------
#plt.scatter(decayZ_apa1, decayX_apa1, c='magenta', s=2.0, alpha=1.0, marker='.', label='Magenta Bias')
#plt.scatter(decayZ_apa2, decayX_apa2, c='magenta', s=2.0, alpha=1.0, marker='.', label='Magenta Bias')
#plt.scatter(decayZ_apa3, decayX_apa3, c='magenta', s=2.0, alpha=1.0, marker='.', label='Magenta Bias')
plt.scatter(decayZ_apa4, decayX_apa4, c='magenta', s=2.0, alpha=1.0, marker='.', label='Magenta Bias')

plt.axis('scaled')
plt.ylim(-450, 450)#z---
plt.xlim(-50, 515)
plt.ylabel('X axis [cm]', labelpad=1, fontsize=5)
plt.xlabel('Z axis [cm]', labelpad=1, fontsize=5)
plt.tick_params(labelsize=4)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.3, zorder=0)
plt.show()







#Starting points distribution:==========================================

print("\n\n\nStarting points distribution: ")

#Z-X plane ploting (Top View)----------------------------------------
plt.figure(figsize=(4,3),dpi=400)

#auxiliary line, along y(geo) and x axis---
aux2 = [0, 465, 465, 0, 0] #y shoud be y---
aux1 = [356, 356, -356, -356, 356]
plt.plot(aux2, aux1, color="blue", linewidth=0.8, linestyle='-')

#Drawing of data points------
#plt.scatter(startZ_apa1, startX_apa1, c='magenta', s=2.0, alpha=1.0, marker='.', label='Magenta Bias')
#plt.scatter(startZ_apa2, startX_apa2, c='magenta', s=2.0, alpha=1.0, marker='.', label='Magenta Bias')
#plt.scatter(startZ_apa3, startX_apa3, c='magenta', s=2.0, alpha=1.0, marker='.', label='Magenta Bias')
plt.scatter(startZ_apa4, startX_apa4, c='magenta', s=2.0, alpha=1.0, marker='.', label='Magenta Bias')

plt.axis('scaled')
plt.ylim(-450, 450)#z---
plt.xlim(-50, 515)
plt.ylabel('X axis [cm]', labelpad=1, fontsize=5)
plt.xlabel('Z axis [cm]', labelpad=1, fontsize=5)
plt.tick_params(labelsize=4)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.3, zorder=0)
plt.show()
# Out:
# Decay points distribution:
# Starting points distribution:

# %% [markdown]
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
#
#
# ### Purification 1: remove abnormal muon signals

# %% [markdown]
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
#
#
# ### Purification 2: Lifetime & Coincidence Cuts

# %%
#After coincidence cut-----------------
mu_lifetime_ns_update_tmp = []
decayX_update_tmp = []
decayY_update_tmp = []
decayZ_update_tmp = []

#After coincidence and lifetime cut---
mu_lifetime_ns_update_2 = []
decayX_update_2 = []
decayY_update_2 = []
decayZ_update_2 = []



for i in range(0, len(coin_update)):
    coin = coin_update[i]
    time = mu_lifetime_ns[i] #mu_lifetime_ns is after "Purification 1"
    x = decayX_update[i]
    y = decayY_update[i]
    z = decayZ_update[i]

    if coin >= 3:
        mu_lifetime_ns_update_tmp.append(time)
        decayX_update_tmp.append(x)
        decayY_update_tmp.append(y)
        decayZ_update_tmp.append(z)

        if 500 <= time <= 16000:
            mu_lifetime_ns_update_2.append(time)
            decayX_update_2.append(x)
            decayY_update_2.append(y)
            decayZ_update_2.append(z)            



print("Keep #coincidence >=3:")    
print("# Purified (further) Candidates [-16000, 16000]: ", len(mu_lifetime_ns_update_tmp))

#Test-------
mu_lifetime_ns_purified_00 = [val for val in mu_lifetime_ns_update_tmp if 0 <= val <= 16000]
mu_lifetime_ns_purified_500 = [val for val in mu_lifetime_ns_update_tmp if 500 <= val <= 16000]
print("# Purified Candidates [0, 16000]: ", len(mu_lifetime_ns_purified_00))
print("# Purified Candidates [500, 16000]: ", len(mu_lifetime_ns_purified_500))

print("\nAfter peakCoin && Lifetiem cuts:")
print("mu_lifetime_ns_update_2: ", len(mu_lifetime_ns_update_2))
print("decayX_update_2        : ", len(decayX_update_2))
print("decayY_update_2        : ", len(decayY_update_2))
print("decayZ_update_2        : ", len(decayZ_update_2))
# Out:
# Keep #coincidence >=3:
# # Purified (further) Candidates [-16000, 16000]:  2261
# # Purified Candidates [0, 16000]:  2261
# # Purified Candidates [500, 16000]:  2192
#
# After peakCoin && Lifetiem cuts:
# mu_lifetime_ns_update_2:  2192
# decayX_update_2        :  2192
# decayY_update_2        :  2192
# decayZ_update_2        :  2192

# %%
# Plotting the histogram (X distribution)---------------
plt.figure(figsize=(4,3),dpi=400)
#APA planes---
plt.plot([-356, -356], [0, 2000], color="blue", linewidth=0.8, linestyle='--')
plt.plot([356, 356], [0, 2000], color="blue", linewidth=0.8, linestyle='--')
#Define the range and bin width
bin_width = 10
range_min = -400
range_max = 400
bins = np.arange(range_min, range_max + bin_width, bin_width)

plt.hist(decayX_update_2, bins=bins, range=(range_min, range_max), edgecolor='magenta', 
         histtype='step', linewidth=0.8)

plt.xlim(-450, 540)
plt.xlabel(r'$x_1$ [cm]', labelpad=2, fontsize=8)
plt.ylabel('#Counts', labelpad=1, fontsize=8)
plt.ylim(0.1, 200)
#plt.yscale('log')
plt.tick_params(labelsize=7)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)
plt.show()  




#Y-Z plane ploting (Side View)----------------------------------------
plt.figure(figsize=(4,3),dpi=400)
#auxiliary line, along y(geo) and x axis---
aux2 = [cageMinY, cageMaxY, cageMaxY, cageMinY, cageMinY] #y shoud be y---
aux1 = [cageMinZ, cageMinZ, cageMaxZ, cageMaxZ, cageMinZ]
plt.plot(aux1, aux2, color="blue", linewidth=0.8, linestyle='-')

#Drawing of data points------
plt.scatter(decayZ_update_2, decayY_update_2, c='magenta', s=2.0, alpha=1.0, marker='.', label='Magenta Bias')

plt.axis('scaled')
plt.xlim(-50, 515)#z---
plt.ylim(-50, 660)
plt.xlabel('Z axis [cm]', labelpad=1, fontsize=5)
plt.ylabel('Y axis [cm]', labelpad=1, fontsize=5)
plt.tick_params(labelsize=4)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.3, zorder=0)
plt.show()  







#Z-X plane ploting (Top View)----------------------------------------
plt.figure(figsize=(4,3),dpi=400)

#auxiliary line, along y(geo) and x axis---
aux2 = [0, 465, 465, 0, 0] #y shoud be y---
aux1 = [356, 356, -356, -356, 356]
plt.plot(aux2, aux1, color="blue", linewidth=0.8, linestyle='-')


#Drawing of data points------
plt.scatter(decayZ_update_2, decayX_update_2, c='magenta', s=2.0, alpha=1.0, marker='.', label='Magenta Bias')


plt.axis('scaled')
plt.ylim(-450, 450)#z---
plt.xlim(-50, 515)
plt.ylabel('X axis [cm]', labelpad=1, fontsize=5)
plt.xlabel('Z axis [cm]', labelpad=1, fontsize=5)
plt.tick_params(labelsize=4)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.3, zorder=0)
plt.show() 





#Y-X plane ploting (Front View)----------------------------------------
plt.figure(figsize=(4,3),dpi=400)
#auxiliary line, along y(geo) and x axis---
aux2 = [0, 610, 610, 0, 0] #y shoud be y---
aux1 = [356, 356, -356, -356, 356]
plt.plot(aux1, aux2, color="blue", linewidth=0.8, linestyle='-')

#Drawing of data points------
plt.scatter(decayX_update_2, decayY_update_2, c='magenta', s=2.0, alpha=1.0, marker='.', label='Magenta Bias')

plt.axis('scaled')
plt.xlim(-450, 450)#z---
plt.ylim(-50, 660)
plt.xlabel('X axis [cm]', labelpad=1, fontsize=5)
plt.ylabel('Y axis [cm]', labelpad=1, fontsize=5)
plt.tick_params(labelsize=4)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.3, zorder=0)
plt.show() 












# Muon Lifetime distribution (NO fitting)--------------------------------------------
plt.figure(figsize=(4, 3), dpi=400)

# Define histogram parameters
bin_width = 500
range_min = 500
range_max = 16000
bins = np.arange(range_min, range_max + bin_width, bin_width)

# Plot histogram-----------------
plt.hist(mu_lifetime_ns_update_2, bins=bins, range=(range_min, range_max),
         edgecolor='blue', histtype='step', linewidth=0.8,
         label='Muon Lifetime')

plt.xlim(0, 16000)
plt.ylim(0, 1000)
plt.xlabel('Time [ns]', fontsize=8)
plt.ylabel('#Counts', fontsize=8)
plt.tick_params(labelsize=7)
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)
plt.legend(loc='upper center', bbox_to_anchor=(0.78, 0.95), fontsize=11, markerscale=5, ncol=1, prop={'size':8})
plt.show()







#Fitting---------------------------------------------------------------------------
plt.figure(figsize=(4, 3), dpi=400)

print("\nLeast Square Fitting:==================")

# Define histogram parameters
bin_width = 500
range_min = 500
range_max = 15500
bins = np.arange(range_min, range_max + bin_width, bin_width)

# Create the histogram and capture counts, bin edges, etc.
n, bin_edges, patches = plt.hist(mu_lifetime_ns_update_2, bins=bins, range=(range_min, range_max),
                                 edgecolor='blue', histtype='step', linewidth=0.8,
                                 label='Muon Lifetime Preliminary')

# Calculate bin centers
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

# Calculate statistical uncertainties (sqrt(n))
yerr = np.sqrt(n)
yerr_plot = np.where(n == 0, 1, yerr)  # Avoid zero division error for empty bins

# Plot error bars on the histogram
plt.errorbar(bin_centers, n, yerr=yerr, fmt='o', color='blue', markersize=2)

# Define the exponential fitting function: N(t) = N0 * exp(-t/tau0) + C
def exp_func(t, N0, tau0, C):
    return N0 * np.exp(-t / tau0) + C

# Least Squares Method------
popt, pcov = curve_fit(exp_func, bin_centers, n, p0=[max(n), 1000, 1], sigma=yerr, absolute_sigma=True)
perr = np.sqrt(np.diag(pcov))  # parameter uncertainties

# Print entries and uncertainties for each bin
print("\nBin information:")
for i in range(len(n)):
    print(f"Bin {i+1}: Range = [{bin_edges[i]:.0f}, {bin_edges[i+1]:.0f}) | "
          f"Center = {bin_centers[i]:.0f} ns | "
          f"Entries = {n[i]:.0f} ± {yerr[i]:.1f}")

# Print results to terminal
print("\nFitted parameters:")
print("N0 = {:.2f} +/- {:.2f}".format(popt[0], perr[0]))
print("tau0 = {:.2f} +/- {:.2f} ns".format(popt[1], perr[1]))
print("C = {:.2f} +/- {:.2f}".format(popt[2], perr[2]))

# Calculate chi-squared
expected = exp_func(bin_centers, *popt)
expected = np.clip(expected, 1e-10, None)  # Avoid division by zero
residuals = n - expected
chi2 = np.sum((residuals / yerr_plot) ** 2)
ndf = len(n) - len(popt)
chi2_ndf = chi2 / ndf

# Print goodness-of-fit summary
print(f"\n[Goodness of Fit] χ² / ndf = {chi2:.1f} / {ndf} = {chi2_ndf:.2f}")

# Print detailed bin-by-bin information
for i, (label, observed, exp_val, res, err) in enumerate(zip(bin_centers, n, expected, residuals, yerr_plot)):
    print(f"Bin {i} (center={label:.2f}): n = {observed:.2f}; expected = {exp_val:.2f}; "
          f"residual = {res:.2f}; residual / yerr = {res / err:.2f}")

# Plot and legend----------
n0_text = f'N₀ = {popt[0]:.0f} ± {perr[0]:.0f}'
tau_text = f'τ = {popt[1]:.0f} ± {perr[1]:.0f} ns'
c_text = f'C = {popt[2]:.1f} ± {perr[2]:.1f}'
chi2_text = f'χ² / ndf = {chi2:.1f} / {ndf}'

t_fit = np.linspace(range_min, range_max, 1000)
fit_line, = plt.plot(t_fit, exp_func(t_fit, *popt), color='red', linestyle='--', label=tau_text)

# Dummy handles for text-only legend entries
dummy_n0 = plt.Line2D([], [], color='none', label=n0_text)
dummy_c = plt.Line2D([], [], color='none', label=c_text)
dummy_chi2 = plt.Line2D([], [], color='none', label=chi2_text)

# Histogram handle
hist_handle = plt.Line2D([], [], color='blue', linestyle='-', label='Muon Lifetime Preliminary')

plt.legend(handles=[hist_handle, fit_line, dummy_n0, dummy_c, dummy_chi2],
           loc='upper center', bbox_to_anchor=(0.7, 0.99),
           fontsize=7, ncol=1, prop={'size': 6})

plt.xlim(0, 16000)
plt.ylim(0.9, 1000)
#plt.yscale('log')
plt.xlabel('Time [ns]', labelpad=2, fontsize=8)
plt.ylabel('#Counts', labelpad=1, fontsize=8)
plt.tick_params(labelsize=7)
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)
plt.show()
# Out:
# Least Square Fitting:==================
#
# Bin information:
# Bin 1: Range = [500, 1000) | Center = 750 ns | Entries = 337 ± 18.4
# Bin 2: Range = [1000, 1500) | Center = 1250 ns | Entries = 340 ± 18.4
# Bin 3: Range = [1500, 2000) | Center = 1750 ns | Entries = 257 ± 16.0
# Bin 4: Range = [2000, 2500) | Center = 2250 ns | Entries = 213 ± 14.6
# Bin 5: Range = [2500, 3000) | Center = 2750 ns | Entries = 171 ± 13.1
# Bin 6: Range = [3000, 3500) | Center = 3250 ns | Entries = 127 ± 11.3
# Bin 7: Range = [3500, 4000) | Center = 3750 ns | Entries = 117 ± 10.8
# Bin 8: Range = [4000, 4500) | Center = 4250 ns | Entries = 93 ± 9.6
# Bin 9: Range = [4500, 5000) | Center = 4750 ns | Entries = 68 ± 8.2
# Bin 10: Range = [5000, 5500) | Center = 5250 ns | Entries = 47 ± 6.9
# Bin 11: Range = [5500, 6000) | Center = 5750 ns | Entries = 50 ± 7.1
# Bin 12: Range = [6000, 6500) | Center = 6250 ns | Entries = 38 ± 6.2
# Bin 13: Range = [6500, 7000) | Center = 6750 ns | Entries = 24 ± 4.9
# Bin 14: Range = [7000, 7500) | Center = 7250 ns | Entries = 27 ± 5.2
# Bin 15: Range = [7500, 8000) | Center = 7750 ns | Entries = 24 ± 4.9
# Bin 16: Range = [8000, 8500) | Center = 8250 ns | Entries = 19 ± 4.4
# Bin 17: Range = [8500, 9000) | Center = 8750 ns | Entries = 19 ± 4.4
# Bin 18: Range = [9000, 9500) | Center = 9250 ns | Entries = 28 ± 5.3
# Bin 19: Range = [9500, 10000) | Center = 9750 ns | Entries = 20 ± 4.5
# Bin 20: Range = [10000, 10500) | Center = 10250 ns | Entries = 19 ± 4.4
# Bin 21: Range = [10500, 11000) | Center = 10750 ns | Entries = 16 ± 4.0
# Bin 22: Range = [11000, 11500) | Center = 11250 ns | Entries = 21 ± 4.6
# Bin 23: Range = [11500, 12000) | Center = 11750 ns | Entries = 19 ± 4.4
# Bin 24: Range = [12000, 12500) | Center = 12250 ns | Entries = 7 ± 2.6
# Bin 25: Range = [12500, 13000) | Center = 12750 ns | Entries = 14 ± 3.7
# Bin 26: Range = [13000, 13500) | Center = 13250 ns | Entries = 18 ± 4.2
# Bin 27: Range = [13500, 14000) | Center = 13750 ns | Entries = 12 ± 3.5
# Bin 28: Range = [14000, 14500) | Center = 14250 ns | Entries = 11 ± 3.3
# Bin 29: Range = [14500, 15000) | Center = 14750 ns | Entries = 18 ± 4.2
# Bin 30: Range = [15000, 15500) | Center = 15250 ns | Entries = 18 ± 4.2
#
# Fitted parameters:
# N0 = 533.40 +/- 23.42
# tau0 = 2125.05 +/- 81.07 ns
# C = 12.13 +/- 1.21
#
# [Goodness of Fit] χ² / ndf = 41.9 / 27 = 1.55
# Bin 0 (center=750.00): n = 337.00; expected = 386.92; residual = -49.92; residual / yerr = -2.72
# Bin 1 (center=1250.00): n = 340.00; expected = 308.34; residual = 31.66; residual / yerr = 1.72
# Bin 2 (center=1750.00): n = 257.00; expected = 246.24; residual = 10.76; residual / yerr = 0.67
# Bin 3 (center=2250.00): n = 213.00; expected = 197.16; residual = 15.84; residual / yerr = 1.09
# Bin 4 (center=2750.00): n = 171.00; expected = 158.37; residual = 12.63; residual / yerr = 0.97
# Bin 5 (center=3250.00): n = 127.00; expected = 127.71; residual = -0.71; residual / yerr = -0.06
# Bin 6 (center=3750.00): n = 117.00; expected = 103.48; residual = 13.52; residual / yerr = 1.25
# Bin 7 (center=4250.00): n = 93.00; expected = 84.33; residual = 8.67; residual / yerr = 0.90
# Bin 8 (center=4750.00): n = 68.00; expected = 69.19; residual = -1.19; residual / yerr = -0.14
# Bin 9 (center=5250.00): n = 47.00; expected = 57.23; residual = -10.23; residual / yerr = -1.49
# Bin 10 (center=5750.00): n = 50.00; expected = 47.77; residual = 2.23; residual / yerr = 0.31
# Bin 11 (center=6250.00): n = 38.00; expected = 40.30; residual = -2.30; residual / yerr = -0.37
# Bin 12 (center=6750.00): n = 24.00; expected = 34.40; residual = -10.40; residual / yerr = -2.12
# Bin 13 (center=7250.00): n = 27.00; expected = 29.73; residual = -2.73; residual / yerr = -0.53
# Bin 14 (center=7750.00): n = 24.00; expected = 26.04; residual = -2.04; residual / yerr = -0.42
# Bin 15 (center=8250.00): n = 19.00; expected = 23.13; residual = -4.13; residual / yerr = -0.95
# Bin 16 (center=8750.00): n = 19.00; expected = 20.82; residual = -1.82; residual / yerr = -0.42
# Bin 17 (center=9250.00): n = 28.00; expected = 19.00; residual = 9.00; residual / yerr = 1.70
# Bin 18 (center=9750.00): n = 20.00; expected = 17.56; residual = 2.44; residual / yerr = 0.55
# Bin 19 (center=10250.00): n = 19.00; expected = 16.42; residual = 2.58; residual / yerr = 0.59
# Bin 20 (center=10750.00): n = 16.00; expected = 15.52; residual = 0.48; residual / yerr = 0.12
# Bin 21 (center=11250.00): n = 21.00; expected = 14.81; residual = 6.19; residual / yerr = 1.35
# Bin 22 (center=11750.00): n = 19.00; expected = 14.25; residual = 4.75; residual / yerr = 1.09
# Bin 23 (center=12250.00): n = 7.00; expected = 13.81; residual = -6.81; residual / yerr = -2.57
# Bin 24 (center=12750.00): n = 14.00; expected = 13.46; residual = 0.54; residual / yerr = 0.15
# Bin 25 (center=13250.00): n = 18.00; expected = 13.18; residual = 4.82; residual / yerr = 1.14
# Bin 26 (center=13750.00): n = 12.00; expected = 12.96; residual = -0.96; residual / yerr = -0.28
# Bin 27 (center=14250.00): n = 11.00; expected = 12.79; residual = -1.79; residual / yerr = -0.54
# Bin 28 (center=14750.00): n = 18.00; expected = 12.65; residual = 5.35; residual / yerr = 1.26
# Bin 29 (center=15250.00): n = 18.00; expected = 12.54; residual = 5.46; residual / yerr = 1.29

# %% [markdown]
# #### Fitting with double-exponential function:
#
# $$
# \large
# N(t) = N_1 \cdot e^{-t / \tau_1} + N_2 \cdot e^{-t / \tau_2} + C
# $$
# where $\tau_2 = 2200 ns$

# %%
#Plot---------------------------------------------------------------------------
plt.figure(figsize=(4, 3), dpi=400)

print("\nLeast Square Fitting:==================")

# Define histogram parameters
bin_width = 500
range_min = 500
range_max = 15500
bins = np.arange(range_min, range_max + bin_width, bin_width)

# Create the histogram and capture counts, bin edges, etc.
n, bin_edges, patches = plt.hist(mu_lifetime_ns_update_2, bins=bins, range=(range_min, range_max),
                                 edgecolor='blue', histtype='step', linewidth=0.8)

# Calculate bin centers
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

# Calculate statistical uncertainties (sqrt(n))
yerr = np.sqrt(n)
yerr_plot = np.where(n == 0, 1, yerr)  # Avoid zero division error for empty bins

# Plot error bars on the histogram
hist_handle = plt.errorbar(bin_centers, n, yerr=yerr, fmt='o', color='blue', markersize=2, label='Muon Lifetime Preliminary')

# Define the double exponential function with fixed tau_2 = 2200 ns
def exp_func_fixed_tau2(t, N1, tau1, N2, C):
    tau2_fixed = 2200  # ns
    return N1 * np.exp(-t / tau1) + N2 * np.exp(-t / tau2_fixed) + C

# Least Squares Method with fixed tau_2-------
# Initial guess: [N1, tau1, N2, C]
popt, pcov = curve_fit(
    exp_func_fixed_tau2, bin_centers, n,
    p0=[max(n)/5, 500, max(n), 10],
    sigma=yerr, absolute_sigma=True,
    maxfev=10000,  # increased from default 1000
    bounds=([0, 0, 0, 0],                 # Lower bounds
            [1000, 2500, 1000, 50])       # Upper bounds

)
perr = np.sqrt(np.diag(pcov))  # parameter uncertainties

# Print entries and uncertainties for each bin
print("\nBin information:")
for i in range(len(n)):
    print(f"Bin {i+1}: Range = [{bin_edges[i]:.0f}, {bin_edges[i+1]:.0f}) | "
          f"Center = {bin_centers[i]:.0f} ns | "
          f"Entries = {n[i]:.0f} ± {yerr[i]:.1f}")

# Print fitted parameters
print("\nFitted parameters:")
print("N1 = {:.2f} +/- {:.2f}".format(popt[0], perr[0]))
print("tau1 = {:.2f} +/- {:.2f} ns".format(popt[1], perr[1]))
print("N2 = {:.2f} +/- {:.2f}".format(popt[2], perr[2]))
print("C = {:.2f} +/- {:.2f}".format(popt[3], perr[3]))

# Calculate expected values and chi-squared
expected = exp_func_fixed_tau2(bin_centers, *popt)
expected = np.clip(expected, 1e-10, None)
residuals = n - expected
chi2 = np.sum((residuals / yerr_plot) ** 2)
ndf = len(n) - len(popt)
chi2_ndf = chi2 / ndf

print(f"\n[Goodness of Fit] χ² / ndf = {chi2:.1f} / {ndf} = {chi2_ndf:.2f}")

# Print detailed bin-by-bin information
for i, (label, observed, exp_val, res, err) in enumerate(zip(bin_centers, n, expected, residuals, yerr_plot)):
    print(f"Bin {i} (center={label:.2f}): n = {observed:.2f}; expected = {exp_val:.2f}; "
          f"residual = {res:.2f}; residual / yerr = {res / err:.2f}")

# Plot and legend----------
func_text = f'Fit: $N_1 e^{{-x/\\tau_1}} + N_2 e^{{-x/2200}} + C$'
n1_text = f'N₁ = {popt[0]:.0f} ± {perr[0]:.0f}'
tau1_text = f'τ₁ = {popt[1]:.0f} ± {perr[1]:.0f} ns'
n2_text = f'N₂ = {popt[2]:.0f} ± {perr[2]:.0f}'
c_text = f'C = {popt[3]:.1f} ± {perr[3]:.1f}'
chi2_text = f'χ² / ndf = {chi2:.1f} / {ndf}'

t_fit = np.linspace(range_min, range_max, 1000)
fit_line, = plt.plot(t_fit, exp_func_fixed_tau2(t_fit, *popt), color='red', linestyle='--', label=func_text)

# Dummy handles for displaying additional info in the legend
dummy_tau1 = plt.Line2D([], [], color='none', label=tau1_text)
dummy_n1 = plt.Line2D([], [], color='none', label=n1_text)
dummy_n2 = plt.Line2D([], [], color='none', label=n2_text)
dummy_c = plt.Line2D([], [], color='none', label=c_text)
dummy_chi2 = plt.Line2D([], [], color='none', label=chi2_text)

# Finalize legend
plt.legend(handles=[hist_handle, fit_line, dummy_tau1, dummy_n1, dummy_n2, dummy_c, dummy_chi2],
           loc='upper center', bbox_to_anchor=(0.7, 0.99),
           fontsize=7, ncol=1, prop={'size': 6})

plt.xlim(0, 16000)
plt.ylim(0.9, 1000)
#plt.yscale('log')
plt.xlabel('Time [ns]', labelpad=2, fontsize=8)
plt.ylabel('#Counts', labelpad=1, fontsize=8)
plt.tick_params(labelsize=7)
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)
plt.show()
# Out:
# Least Square Fitting:==================
#
# Bin information:
# Bin 1: Range = [500, 1000) | Center = 750 ns | Entries = 337 ± 18.4
# Bin 2: Range = [1000, 1500) | Center = 1250 ns | Entries = 340 ± 18.4
# Bin 3: Range = [1500, 2000) | Center = 1750 ns | Entries = 257 ± 16.0
# Bin 4: Range = [2000, 2500) | Center = 2250 ns | Entries = 213 ± 14.6
# Bin 5: Range = [2500, 3000) | Center = 2750 ns | Entries = 171 ± 13.1
# Bin 6: Range = [3000, 3500) | Center = 3250 ns | Entries = 127 ± 11.3
# Bin 7: Range = [3500, 4000) | Center = 3750 ns | Entries = 117 ± 10.8
# Bin 8: Range = [4000, 4500) | Center = 4250 ns | Entries = 93 ± 9.6
# Bin 9: Range = [4500, 5000) | Center = 4750 ns | Entries = 68 ± 8.2
# Bin 10: Range = [5000, 5500) | Center = 5250 ns | Entries = 47 ± 6.9
# Bin 11: Range = [5500, 6000) | Center = 5750 ns | Entries = 50 ± 7.1
# Bin 12: Range = [6000, 6500) | Center = 6250 ns | Entries = 38 ± 6.2
# Bin 13: Range = [6500, 7000) | Center = 6750 ns | Entries = 24 ± 4.9
# Bin 14: Range = [7000, 7500) | Center = 7250 ns | Entries = 27 ± 5.2
# Bin 15: Range = [7500, 8000) | Center = 7750 ns | Entries = 24 ± 4.9
# Bin 16: Range = [8000, 8500) | Center = 8250 ns | Entries = 19 ± 4.4
# Bin 17: Range = [8500, 9000) | Center = 8750 ns | Entries = 19 ± 4.4
# Bin 18: Range = [9000, 9500) | Center = 9250 ns | Entries = 28 ± 5.3
# Bin 19: Range = [9500, 10000) | Center = 9750 ns | Entries = 20 ± 4.5
# Bin 20: Range = [10000, 10500) | Center = 10250 ns | Entries = 19 ± 4.4
# Bin 21: Range = [10500, 11000) | Center = 10750 ns | Entries = 16 ± 4.0
# Bin 22: Range = [11000, 11500) | Center = 11250 ns | Entries = 21 ± 4.6
# Bin 23: Range = [11500, 12000) | Center = 11750 ns | Entries = 19 ± 4.4
# Bin 24: Range = [12000, 12500) | Center = 12250 ns | Entries = 7 ± 2.6
# Bin 25: Range = [12500, 13000) | Center = 12750 ns | Entries = 14 ± 3.7
# Bin 26: Range = [13000, 13500) | Center = 13250 ns | Entries = 18 ± 4.2
# Bin 27: Range = [13500, 14000) | Center = 13750 ns | Entries = 12 ± 3.5
# Bin 28: Range = [14000, 14500) | Center = 14250 ns | Entries = 11 ± 3.3
# Bin 29: Range = [14500, 15000) | Center = 14750 ns | Entries = 18 ± 4.2
# Bin 30: Range = [15000, 15500) | Center = 15250 ns | Entries = 18 ± 4.2
#
# Fitted parameters:
# N1 = 533.41 +/- 33115.86
# tau1 = 2125.04 +/- 4714.86 ns
# N2 = 0.00 +/- 33145.48
# C = 12.13 +/- 1.90
#
# [Goodness of Fit] χ² / ndf = 41.9 / 26 = 1.61
# Bin 0 (center=750.00): n = 337.00; expected = 386.92; residual = -49.92; residual / yerr = -2.72
# Bin 1 (center=1250.00): n = 340.00; expected = 308.34; residual = 31.66; residual / yerr = 1.72
# Bin 2 (center=1750.00): n = 257.00; expected = 246.24; residual = 10.76; residual / yerr = 0.67
# Bin 3 (center=2250.00): n = 213.00; expected = 197.16; residual = 15.84; residual / yerr = 1.09
# Bin 4 (center=2750.00): n = 171.00; expected = 158.37; residual = 12.63; residual / yerr = 0.97
# Bin 5 (center=3250.00): n = 127.00; expected = 127.71; residual = -0.71; residual / yerr = -0.06
# Bin 6 (center=3750.00): n = 117.00; expected = 103.48; residual = 13.52; residual / yerr = 1.25
# Bin 7 (center=4250.00): n = 93.00; expected = 84.33; residual = 8.67; residual / yerr = 0.90
# Bin 8 (center=4750.00): n = 68.00; expected = 69.19; residual = -1.19; residual / yerr = -0.14
# Bin 9 (center=5250.00): n = 47.00; expected = 57.23; residual = -10.23; residual / yerr = -1.49
# Bin 10 (center=5750.00): n = 50.00; expected = 47.77; residual = 2.23; residual / yerr = 0.31
# Bin 11 (center=6250.00): n = 38.00; expected = 40.30; residual = -2.30; residual / yerr = -0.37
# Bin 12 (center=6750.00): n = 24.00; expected = 34.40; residual = -10.40; residual / yerr = -2.12
# Bin 13 (center=7250.00): n = 27.00; expected = 29.73; residual = -2.73; residual / yerr = -0.53
# Bin 14 (center=7750.00): n = 24.00; expected = 26.04; residual = -2.04; residual / yerr = -0.42
# Bin 15 (center=8250.00): n = 19.00; expected = 23.13; residual = -4.13; residual / yerr = -0.95
# Bin 16 (center=8750.00): n = 19.00; expected = 20.82; residual = -1.82; residual / yerr = -0.42
# Bin 17 (center=9250.00): n = 28.00; expected = 19.00; residual = 9.00; residual / yerr = 1.70
# Bin 18 (center=9750.00): n = 20.00; expected = 17.56; residual = 2.44; residual / yerr = 0.55
# Bin 19 (center=10250.00): n = 19.00; expected = 16.42; residual = 2.58; residual / yerr = 0.59
# Bin 20 (center=10750.00): n = 16.00; expected = 15.52; residual = 0.48; residual / yerr = 0.12
# Bin 21 (center=11250.00): n = 21.00; expected = 14.81; residual = 6.19; residual / yerr = 1.35
# Bin 22 (center=11750.00): n = 19.00; expected = 14.25; residual = 4.75; residual / yerr = 1.09
# Bin 23 (center=12250.00): n = 7.00; expected = 13.81; residual = -6.81; residual / yerr = -2.57
# Bin 24 (center=12750.00): n = 14.00; expected = 13.46; residual = 0.54; residual / yerr = 0.15
# Bin 25 (center=13250.00): n = 18.00; expected = 13.18; residual = 4.82; residual / yerr = 1.14
# Bin 26 (center=13750.00): n = 12.00; expected = 12.96; residual = -0.96; residual / yerr = -0.28
# Bin 27 (center=14250.00): n = 11.00; expected = 12.79; residual = -1.79; residual / yerr = -0.54
# Bin 28 (center=14750.00): n = 18.00; expected = 12.65; residual = 5.35; residual / yerr = 1.26
# Bin 29 (center=15250.00): n = 18.00; expected = 12.54; residual = 5.46; residual / yerr = 1.29

# %% [markdown]
# <br />
# <br />
#
# ### Check Detection Rate:
#
# #### decay points After TPC cut are from statScript/local/<certain run>/applyCut_print/newResult

# %%
print("Final candidates (Space & MS & MH & wvfCoin & peakCoin & [500, 16000]): ", len(decayX_update_2), 
      "({:.2f}%)".format(len(decayX_update_2)/len(decayX_TPC)*100))

print("\nInitial candidates (Space & MS & MH): ", len(decayY_TPC))
print("Initial candidates (Space & MS & MH): ", len(decayZ_TPC))



# Plotting the histogram (X distribution)---------------
fig, ax1 = plt.subplots(figsize=(4, 3), dpi=400)

#Define the range and bin width
bin_width = 10
range_min = -400
range_max = 400
bins = np.arange(range_min, range_max + bin_width, bin_width)
bin_centers = (bins[:-1] + bins[1:]) / 2

# --- Histogram counts ---
n_initial, _ = np.histogram(decayX_TPC, bins=bins)
n_final, _ = np.histogram(decayX_update_2, bins=bins)

# --- Ratio Calculation (only for [-360, 360]) ---
ratio = []
ratio_centers = []

print("\nBin Center | Final / Initial Ratio")
print("-------------------------------")
for center, ni, nf in zip(bin_centers, n_initial, n_final):
    if -360 <= center <= 360:
        r = nf / ni if ni > 0 else np.nan
        ratio.append(r)
        ratio_centers.append(center)
        if ni > 0:
            print(f"{center:9.1f} | {r:.3f}")
        else:
            print(f"{center:9.1f} |   NaN")


#APA planes---
plt.plot([-356, -356], [0, 10000], color="blue", linewidth=0.8, linestyle='--')
plt.plot([356, 356], [0, 10000], color="blue", linewidth=0.8, linestyle='--')


# Plot histograms
ax1.hist(bins[:-1], bins=bins, weights=n_initial, edgecolor='black',
         histtype='step', linewidth=0.8, label='TPC-cut Candidates')
ax1.hist(bins[:-1], bins=bins, weights=n_final, edgecolor='magenta',
         histtype='step', linewidth=0.8, label='Final Candidates')


ax1.set_ylabel('Counts')
ax1.grid(True, linestyle='--', linewidth=0.5)
ax1.legend(loc='upper center', bbox_to_anchor=(0.8, 0.99), fontsize=9, markerscale=5, ncol=1, prop={'size': 6})
ax1.set_xlim(-400, 400)
ax1.set_ylim(0.1, 10000)
ax1.set_xlabel('Drift direction [cm]', labelpad=1, fontsize=6)
ax1.set_ylabel('#Counts', labelpad=1, fontsize=7)
ax1.set_yscale('log')
ax1.tick_params(labelsize=6)


# Secondary y-axis for ratio
ax2 = ax1.twinx()

ax2.plot(ratio_centers, ratio, 'o-', color='green', markersize=1, linewidth=0.8, label='Final / Initial Ratio')

ax2.set_ylabel('Ratio', labelpad=1, fontsize=8, color='green', rotation=90)
ax2.yaxis.set_label_position("right")
ax2.yaxis.set_label_coords(1.09, 0.5)  # (x, y) in axis coordinates

ax2.tick_params(labelsize=7, axis='y', labelcolor='green')
ax2.set_ylim(0, np.nanmax(ratio) * 1.2)


# Final layout
#plt.tight_layout()
plt.show()
# Out:
# Initial candidates (Space & MS & MH):  12757
# Final candidates (Space & MS & MH & wvfCoin & peakCoin & [500, 16000]):  2192 (17.18%)
#
# Initial candidates (Space & MS & MH):  12757
# Initial candidates (Space & MS & MH):  12757
#
# Bin Center | Final / Initial Ratio
# -------------------------------
#    -355.0 | 0.500
#    -345.0 | 0.129
#    -335.0 | 0.235
#    -325.0 | 0.217
#    -315.0 | 0.469
#    -305.0 | 0.424
#    -295.0 | 0.528
#    -285.0 | 0.366
#    -275.0 | 0.426
#    -265.0 | 0.518
#    -255.0 | 0.511
#    -245.0 | 0.426
#    -235.0 | 0.344
#    -225.0 | 0.323
#    -215.0 | 0.383
#    -205.0 | 0.423
#    -195.0 | 0.264
#    -185.0 | 0.360
#    -175.0 | 0.324
#    -165.0 | 0.222
#    -155.0 | 0.200
#    -145.0 | 0.239
#    -135.0 | 0.287
#    -125.0 | 0.199
#    -115.0 | 0.186
#    -105.0 | 0.171
#     -95.0 | 0.172
#     -85.0 | 0.150
#     -75.0 | 0.085
#     -65.0 | 0.112
#     -55.0 | 0.097
#     -45.0 | 0.068
#     -35.0 | 0.057
#     -25.0 | 0.055
#     -15.0 | 0.056
#      -5.0 | 0.040
#       5.0 | 0.086
#      15.0 | 0.084
#      25.0 | 0.110
#      35.0 | 0.141
#      45.0 | 0.126
#      55.0 | 0.161
#      65.0 | 0.238
#      75.0 | 0.237
#      85.0 | 0.268
#      95.0 | 0.328
#     105.0 | 0.419
#     115.0 | 0.470
#     125.0 | 0.507
#     135.0 | 0.456
#     145.0 | 0.604
#     155.0 | 0.604
#     165.0 | 0.571
#     175.0 | 0.476
#     185.0 | 0.630
#     195.0 | 0.625
#     205.0 | 0.526
#     215.0 | 0.613
#     225.0 | 0.429
#     235.0 | 0.467
#     245.0 | 0.696
#     255.0 | 0.708
#     265.0 | 0.750
#     275.0 | 0.659
#     285.0 | 0.684
#     295.0 | 0.643
#     305.0 | 0.517
#     315.0 | 0.610
#     325.0 | 0.585
#     335.0 | 0.674
#     345.0 | 0.514
#     355.0 | 0.500

# %% [markdown]
# <br />
#
# #### Split into 4 TPC chambers:

# %%
#After TPC cut:
decayX_TPC_apa24 = []#Candidates for APA 2 and 4---
decayX_TPC_apa3 = []


#Final candidates:
decayX_update_2_apa24 = []
decayX_update_2_apa3 = []

for i in range(0, len(decayZ_update_2)):
    z = decayZ_update_2[i]
    x = decayX_update_2[i]

    if z > 231.266:
        decayX_update_2_apa24.append(x)
    else:
        decayX_update_2_apa3.append(x)

print("\nFinal candidates:")
print("#decayX_update_2: ", len(decayX_update_2))
print("#decayX_update_2_apa24: ", len(decayX_update_2_apa24), 
      "({:.2f}%)".format(len(decayX_update_2_apa24)/len(decayX_update_2)*100))
print("#decayX_update_2_apa3: ", len(decayX_update_2_apa3), 
      "({:.2f}%)".format(len(decayX_update_2_apa3)/len(decayX_update_2)*100))





# Plotting the histogram (X distribution)---------------
fig, ax1 = plt.subplots(figsize=(4, 3), dpi=400)

#Define the range and bin width
bin_width = 10
range_min = -400
range_max = 400
bins = np.arange(range_min, range_max + bin_width, bin_width)
bin_centers = (bins[:-1] + bins[1:]) / 2

#APA2 & APA4--------------------------------------------
# --- Histogram counts ---
n_initial_apa24, _ = np.histogram(decayX_TPC_apa24, bins=bins)
n_final_apa24, _ = np.histogram(decayX_update_2_apa24, bins=bins)

# --- Ratio Calculation (only for [-360, 360]) ---
ratio_apa24 = []
ratio_centers_apa24 = []

print("\n\n------ APA2 & APA4: ------")
print("Bin Center | Final / Initial Ratio")
print("-------------------------------")
for center, ni, nf in zip(bin_centers, n_initial_apa24, n_final_apa24):
    if -360 <= center <= 360:
        r = nf / ni if ni > 0 else np.nan
        ratio_apa24.append(r)
        ratio_centers_apa24.append(center)
        if ni > 0:
            print(f"{center:9.1f} | {r:.3f}")
        else:
            print(f"{center:9.1f} |   NaN")



#APA3--------------------------------------------
# --- Histogram counts ---
n_initial_apa3, _ = np.histogram(decayX_TPC_apa3, bins=bins)
n_final_apa3, _ = np.histogram(decayX_update_2_apa3, bins=bins)

# --- Ratio Calculation (only for [-360, 360]) ---
ratio_apa3 = []
ratio_centers_apa3 = []

print("\n\n------ APA3: ------")
print("Bin Center | Final / Initial Ratio")
print("-------------------------------")
for center, ni, nf in zip(bin_centers, n_initial_apa3, n_final_apa3):
    if 0 <= center <= 350: # x=355, the entry is zero---
        r = nf / ni if ni > 0 else np.nan
        ratio_apa3.append(r)
        ratio_centers_apa3.append(center)
        if ni > 0:
            print(f"{center:9.1f} | {r:.3f}")
        else:
            print(f"{center:9.1f} |   NaN")



#APA planes-------------
plt.plot([-356, -356], [0, 10000], color="blue", linewidth=0.8, linestyle='--')
plt.plot([356, 356], [0, 10000], color="blue", linewidth=0.8, linestyle='--')


# Plot histograms
#APA 2 & 4---
ax1.hist(bins[:-1], bins=bins, weights=n_initial_apa24, edgecolor='black',
         histtype='step', linewidth=0.8, label='APA2 & APA4 Initial')
ax1.hist(bins[:-1], bins=bins, weights=n_final_apa24, edgecolor='magenta',
         histtype='step', linewidth=0.8, label='APA2 & APA4 Final')

#APA 3---
#ax1.hist(bins[:-1], bins=bins, weights=n_initial_apa3, edgecolor='black',
#         histtype='step', linewidth=0.8, label='APA3 Initial')
#ax1.hist(bins[:-1], bins=bins, weights=n_final_apa3, edgecolor='magenta',
#         histtype='step', linewidth=0.8, label='APA3 Final')


ax1.set_ylabel('Counts')
ax1.grid(True, linestyle='--', linewidth=0.5)
ax1.legend(loc='upper center', bbox_to_anchor=(0.2, 0.99), fontsize=9, markerscale=5, ncol=1, prop={'size': 6})
ax1.set_xlim(-400, 400)
ax1.set_ylim(0.1, 10000)
ax1.set_xlabel('Drift direction [cm]', labelpad=1, fontsize=6)
ax1.set_ylabel('#Counts', labelpad=1, fontsize=7)
ax1.set_yscale('log')
ax1.tick_params(labelsize=6)



# Secondary y-axis for ratio
ax2 = ax1.twinx()


#APA2 & APA4:
ax2.plot(ratio_centers_apa24, ratio_apa24, 'o-', color='green', markersize=1, linewidth=0.8, label='Final / Initial Ratio')

#APA3:
#ax2.plot(ratio_centers_apa3, ratio_apa3, 'o-', color='green', markersize=1, linewidth=0.8, label='Final / Initial Ratio')

ax2.set_ylabel('Ratio', labelpad=1, fontsize=8, color='green', rotation=90)
ax2.yaxis.set_label_position("right")
ax2.yaxis.set_label_coords(1.09, 0.5)  # (x, y) in axis coordinates

ax2.tick_params(labelsize=7, axis='y', labelcolor='green')
ax2.set_ylim(0, 1.0)


# Final layout
#plt.tight_layout()
plt.show()
# Out:
# Candidates after TPC cuts:
# #decayX_TPC:  12757
# #decayX_TPC_apa24:  9893 (77.55%)
# #decayX_TPC_apa3:  2864 (22.45%)
#
# Final candidates:
# #decayX_update_2:  2192
# #decayX_update_2_apa24:  1769 (80.70%)
# #decayX_update_2_apa3:  423 (19.30%)
#
#
# ------ APA2 & APA4: ------
# Bin Center | Final / Initial Ratio
# -------------------------------
#    -355.0 | 0.750
#    -345.0 | 0.265
#    -335.0 | 0.308
#    -325.0 | 0.323
#    -315.0 | 0.577
#    -305.0 | 0.500
#    -295.0 | 0.559
#    -285.0 | 0.455
#    -275.0 | 0.500
#    -265.0 | 0.592
#    -255.0 | 0.605
#    -245.0 | 0.500
#    -235.0 | 0.423
#    -225.0 | 0.345
#    -215.0 | 0.456
#    -205.0 | 0.461
#    -195.0 | 0.295
#    -185.0 | 0.421
#    -175.0 | 0.373
#    -165.0 | 0.260
#    -155.0 | 0.234
#    -145.0 | 0.290
#    -135.0 | 0.327
#    -125.0 | 0.236
#    -115.0 | 0.220
#    -105.0 | 0.199
#     -95.0 | 0.195
#     -85.0 | 0.173
#     -75.0 | 0.097
#     -65.0 | 0.131
#     -55.0 | 0.109
#     -45.0 | 0.078
#     -35.0 | 0.065
#     -25.0 | 0.063
#     -15.0 | 0.065
#      -5.0 | 0.055
#       5.0 | 0.090
#      15.0 | 0.058
#      25.0 | 0.124
#      35.0 | 0.148
#      45.0 | 0.082
#      55.0 | 0.173
#      65.0 | 0.196
#      75.0 | 0.220
#      85.0 | 0.227
#      95.0 | 0.338
#     105.0 | 0.412
#     115.0 | 0.483
#     125.0 | 0.511
#     135.0 | 0.577
#     145.0 | 0.667
#     155.0 | 0.667
#     165.0 | 0.500
#     175.0 | 0.143
#     185.0 | 0.462
#     195.0 | 0.450
#     205.0 | 0.500
#     215.0 | 0.533
#     225.0 | 0.533
#     235.0 | 0.375
#     245.0 | 0.765
#     255.0 | 0.818
#     265.0 | 0.714
#     275.0 | 0.778
#     285.0 | 0.625
#     295.0 | 0.857
#     305.0 | 0.643
#     315.0 | 0.667
#     325.0 | 0.562
#     335.0 | 0.682
#     345.0 | 0.529
#     355.0 | 0.000
#
#
# ------ APA3: ------
# Bin Center | Final / Initial Ratio
# -------------------------------
#       5.0 | 0.082
#      15.0 | 0.113
#      25.0 | 0.092
#      35.0 | 0.132
#      45.0 | 0.181
#      55.0 | 0.146
#      65.0 | 0.289
#      75.0 | 0.267
#      85.0 | 0.333
#      95.0 | 0.314
#     105.0 | 0.426
#     115.0 | 0.459
#     125.0 | 0.500
#     135.0 | 0.355
#     145.0 | 0.567
#     155.0 | 0.500
#     165.0 | 0.647
#     175.0 | 0.643
#     185.0 | 0.786
#     195.0 | 0.917
#     205.0 | 0.556
#     215.0 | 0.688
#     225.0 | 0.308
#     235.0 | 0.571
#     245.0 | 0.500
#     255.0 | 0.615
#     265.0 | 0.778
#     275.0 | 0.565
#     285.0 | 0.727
#     295.0 | 0.429
#     305.0 | 0.400
#     315.0 | 0.565
#     325.0 | 0.619
#     335.0 | 0.667
#     345.0 | 0.500

# %% [markdown]
# <br />
#
# ### Comparison among different APAs:

# %%
# Plotting the histogram (X distribution)---------------
plt.figure(figsize=(4,3),dpi=400)
#APA planes---
plt.plot([-356, -356], [0, 2000], color="blue", linewidth=0.8, linestyle='--')
plt.plot([356, 356], [0, 2000], color="blue", linewidth=0.8, linestyle='--')
#Define the range and bin width
bin_width = 10
range_min = -400
range_max = 400
bins = np.arange(range_min, range_max + bin_width, bin_width)

plt.hist(decayX_update_2, bins=bins, range=(range_min, range_max), edgecolor='black', 
         histtype='step', linewidth=0.8, label='Final')
plt.hist(decayX_update_2_apa24, bins=bins, range=(range_min, range_max), edgecolor='magenta', 
         histtype='step', linewidth=0.6, label='Final of APA2 & 4')
plt.hist(decayX_update_2_apa3, bins=bins, range=(range_min, range_max), edgecolor='blue', 
         histtype='step', linewidth=0.6, label='Final of APA3')

plt.xlim(-450, 540)
plt.xlabel(r'$x_1$ [cm]', labelpad=2, fontsize=8)
plt.ylabel('#Counts', labelpad=1, fontsize=8)
plt.ylim(0.1, 200)
#plt.yscale('log')
plt.tick_params(labelsize=7)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)
plt.legend(loc='upper center', bbox_to_anchor=(0.75, 0.95), fontsize=9, markerscale=4, ncol=1, prop={'size':6})
plt.show()  






# Plotting the histogram (X distribution)---------------
plt.figure(figsize=(4,3),dpi=400)
#APA planes---
plt.plot([-356, -356], [0, 2000], color="blue", linewidth=0.8, linestyle='--')
plt.plot([356, 356], [0, 2000], color="blue", linewidth=0.8, linestyle='--')
#Define the range and bin width
bin_width = 10
range_min = -400
range_max = 400
bins = np.arange(range_min, range_max + bin_width, bin_width)

plt.hist(decayX_TPC, bins=bins, range=(range_min, range_max), edgecolor='black', 
         histtype='step', linewidth=0.8, label='Initial')
plt.hist(decayX_TPC_apa24, bins=bins, range=(range_min, range_max), edgecolor='magenta', 
         histtype='step', linewidth=0.6, label='Initial of APA2 & 4')
plt.hist(decayX_TPC_apa3, bins=bins, range=(range_min, range_max), edgecolor='blue', 
         histtype='step', linewidth=0.6, label='Initial of APA3')

plt.xlim(-450, 540)
plt.xlabel(r'$x_1$ [cm]', labelpad=2, fontsize=8)
plt.ylabel('#Counts', labelpad=1, fontsize=8)
plt.ylim(0.1, 2000)
#plt.yscale('log')
plt.tick_params(labelsize=7)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)
plt.legend(loc='upper center', bbox_to_anchor=(0.75, 0.95), fontsize=9, markerscale=4, ncol=1, prop={'size':6})
plt.show()  







#Z-X plane ploting (Top View)----------------------------------------
plt.figure(figsize=(4,3),dpi=400)

#auxiliary line, along y(geo) and x axis---
aux2 = [0, 465, 465, 0, 0] #y shoud be y---
aux1 = [356, 356, -356, -356, 356]
plt.plot(aux2, aux1, color="blue", linewidth=0.8, linestyle='-')


#Drawing of data points------
plt.scatter(decayZ_TPC, decayX_TPC, c='magenta', s=2.0, alpha=1.0, marker='.', label='Magenta Bias')


plt.axis('scaled')
plt.ylim(-450, 450)#z---
plt.xlim(-50, 515)
plt.ylabel('X axis [cm]', labelpad=1, fontsize=5)
plt.xlabel('Z axis [cm]', labelpad=1, fontsize=5)
plt.tick_params(labelsize=4)#set the size of ticks---
plt.grid(color='gray', linestyle='--', linewidth=0.3, zorder=0)
plt.show()

# %% [markdown]
# <br />
#
#
# ### Among beam direction:

# %%
#After TPC cut:
decayZ_TPC_apa12 = []#Candidates for APA 2 and 4---
decayZ_TPC_apa34 = []

for i in range(0, len(decayZ_TPC)):
    z = decayZ_TPC[i]
    x = decayX_TPC[i]

    if x < 0:
        decayZ_TPC_apa12.append(z)
    else:
        decayZ_TPC_apa34.append(z)

print("Candidates after TPC cuts:")
print("#decayZ_TPC: ", len(decayZ_TPC))
print("#decayZ_TPC_apa12: ", len(decayZ_TPC_apa12), "({:.2f}%)".format(len(decayZ_TPC_apa12)/len(decayZ_TPC)*100))
print("#decayZ_TPC_apa34: ", len(decayZ_TPC_apa34), "({:.2f}%)".format(len(decayZ_TPC_apa34)/len(decayZ_TPC)*100))


#Final candidates:
decayZ_update_2_apa12 = []
decayZ_update_2_apa34 = []

for i in range(0, len(decayZ_update_2)):
    z = decayZ_update_2[i]
    x = decayX_update_2[i]

    if x < 0:
        decayZ_update_2_apa12.append(z)
    else:
        decayZ_update_2_apa34.append(z)

print("\nFinal candidates:")
print("#decayZ_update_2_apa12: ", len(decayZ_update_2_apa12))
print("#decayZ_update_2_apa34: ", len(decayZ_update_2_apa34), 
      "({:.2f}%)".format(len(decayZ_update_2_apa12)/len(decayZ_update_2)*100))
print("#decayZ_update_2_apa34: ", len(decayX_update_2_apa3), 
      "({:.2f}%)".format(len(decayZ_update_2_apa34)/len(decayZ_update_2)*100))








# Plotting the histogram (X distribution)-------------------------------------
fig, ax1 = plt.subplots(figsize=(4, 3), dpi=400)

#Define the range and bin width
bin_width = 10
range_min = 0
range_max = 450
bins = np.arange(range_min, range_max + bin_width, bin_width)
bin_centers = (bins[:-1] + bins[1:]) / 2

#APA12--------------------------------------------
# --- Histogram counts ---
n_initial_apa12, _ = np.histogram(decayZ_TPC_apa12, bins=bins)
n_final_apa12, _ = np.histogram(decayZ_update_2_apa12, bins=bins)

# --- Ratio Calculation (only for [-360, 360]) ---
ratio_apa12 = []
ratio_centers_apa12 = []

print("\n\n------ APA1 & APA2: ------")
print("Bin Center | Final / Initial Ratio")
print("-------------------------------")
for center, ni, nf in zip(bin_centers, n_initial_apa12, n_final_apa12):
    if 30 <= center <= 440:
        r = nf / ni if ni > 0 else np.nan
        ratio_apa12.append(r)
        ratio_centers_apa12.append(center)
        if ni > 0:
            print(f"{center:9.1f} | {r:.3f}")
        else:
            print(f"{center:9.1f} |   NaN")


#APA34--------------------------------------------
# --- Histogram counts ---
n_initial_apa34, _ = np.histogram(decayZ_TPC_apa34, bins=bins)
n_final_apa34, _ = np.histogram(decayZ_update_2_apa34, bins=bins)

# --- Ratio Calculation (only for [-360, 360]) ---
ratio_apa34 = []
ratio_centers_apa34 = []

print("\n\n------ APA3 & APA4: ------")
print("Bin Center | Final / Initial Ratio")
print("-------------------------------")
for center, ni, nf in zip(bin_centers, n_initial_apa34, n_final_apa34):
    if 30 <= center <= 440:
        r = nf / ni if ni > 0 else np.nan
        ratio_apa34.append(r)
        ratio_centers_apa34.append(center)
        if ni > 0:
            print(f"{center:9.1f} | {r:.3f}")
        else:
            print(f"{center:9.1f} |   NaN")




# Plot histograms
#APA 1 & 2---
ax1.hist(bins[:-1], bins=bins, weights=n_initial_apa12, edgecolor='black',
         histtype='step', linewidth=0.8, label='APA1 & APA2 Initial')
ax1.hist(bins[:-1], bins=bins, weights=n_final_apa12, edgecolor='magenta',
         histtype='step', linewidth=0.8, label='APA1 & APA2 Final')

#APA 3 & 4---
ax1.hist(bins[:-1], bins=bins, weights=n_initial_apa34, edgecolor='blue',
         histtype='step', linewidth=0.8, label='APA3 & APA4 Initial')
ax1.hist(bins[:-1], bins=bins, weights=n_final_apa34, edgecolor='red',
         histtype='step', linewidth=0.8, label='APA3 & APA4 Final')


ax1.set_ylabel('Counts')
ax1.grid(True, linestyle='--', linewidth=0.5)
ax1.legend(loc='upper center', bbox_to_anchor=(0.2, 0.99), fontsize=9, markerscale=5, ncol=1, prop={'size': 6})
ax1.set_xlim(0, 450)
ax1.set_ylim(0.1, 10000)
ax1.set_xlabel('Drift direction [cm]', labelpad=1, fontsize=6)
ax1.set_ylabel('#Counts', labelpad=1, fontsize=7)
ax1.set_yscale('log')
ax1.tick_params(labelsize=6)



# Secondary y-axis for ratio
ax2 = ax1.twinx()


#APA1 & 2:
ax2.plot(ratio_centers_apa12, ratio_apa12, 'o-', color='green', markersize=1, linewidth=0.8, label='APA1 & APA2 Ratio')

#APA3 & 4:
ax2.plot(ratio_centers_apa34, ratio_apa34, 'o--', color='green', markersize=1, linewidth=0.8, label='APA3 & APA4 Ratio')

ax2.set_ylabel('Ratio', labelpad=1, fontsize=8, color='green', rotation=90)
ax2.yaxis.set_label_position("right")
ax2.yaxis.set_label_coords(1.09, 0.5)  # (x, y) in axis coordinates
ax2.legend(loc='upper center', bbox_to_anchor=(0.7, 0.99), fontsize=9, markerscale=3, ncol=1, prop={'size': 6})
ax2.tick_params(labelsize=7, axis='y', labelcolor='green')
ax2.set_ylim(0, np.nanmax(ratio) * 1.2)


# Final layout
#plt.tight_layout()
plt.show()
# Out:
# Candidates after TPC cuts:
# #decayZ_TPC:  12757
# #decayZ_TPC_apa12:  9530 (74.70%)
# #decayZ_TPC_apa34:  3227 (25.30%)
#
# Final candidates:
# #decayZ_update_2_apa12:  1312
# #decayZ_update_2_apa34:  880 (59.85%)
# #decayZ_update_2_apa34:  423 (40.15%)
#
#
# ------ APA1 & APA2: ------
# Bin Center | Final / Initial Ratio
# -------------------------------
#      35.0 | 0.000
#      45.0 | 0.000
#      55.0 | 0.000
#      65.0 | 0.000
#      75.0 | 0.000
#      85.0 | 0.000
#      95.0 | 0.000
#     105.0 | 0.000
#     115.0 | 0.000
#     125.0 | 0.000
#     135.0 | 0.000
#     145.0 | 0.000
#     155.0 | 0.000
#     165.0 | 0.000
#     175.0 | 0.000
#     185.0 | 0.000
#     195.0 | 0.000
#     205.0 | 0.000
#     215.0 | 0.000
#     225.0 | 0.000
#     235.0 | 0.071
#     245.0 | 0.090
#     255.0 | 0.089
#     265.0 | 0.102
#     275.0 | 0.090
#     285.0 | 0.106
#     295.0 | 0.170
#     305.0 | 0.196
#     315.0 | 0.204
#     325.0 | 0.215
#     335.0 | 0.217
#     345.0 | 0.186
#     355.0 | 0.167
#     365.0 | 0.173
#     375.0 | 0.180
#     385.0 | 0.181
#     395.0 | 0.170
#     405.0 | 0.181
#     415.0 | 0.210
#     425.0 | 0.171
#     435.0 | 0.149
#
#
# ------ APA3 & APA4: ------
# Bin Center | Final / Initial Ratio
# -------------------------------
#      35.0 | 0.375
#      45.0 | 0.233
#      55.0 | 0.255
#      65.0 | 0.274
#      75.0 | 0.472
#      85.0 | 0.298
#      95.0 | 0.321
#     105.0 | 0.275
#     115.0 | 0.344
#     125.0 | 0.308
#     135.0 | 0.243
#     145.0 | 0.382
#     155.0 | 0.337
#     165.0 | 0.234
#     175.0 | 0.194
#     185.0 | 0.373
#     195.0 | 0.247
#     205.0 | 0.244
#     215.0 | 0.226
#     225.0 | 0.261
#     235.0 | 0.246
#     245.0 | 0.269
#     255.0 | 0.271
#     265.0 | 0.247
#     275.0 | 0.266
#     285.0 | 0.255
#     295.0 | 0.296
#     305.0 | 0.230
#     315.0 | 0.269
#     325.0 | 0.312
#     335.0 | 0.220
#     345.0 | 0.242
#     355.0 | 0.210
#     365.0 | 0.274
#     375.0 | 0.292
#     385.0 | 0.143
#     395.0 | 0.260
#     405.0 | 0.296
#     415.0 | 0.330
#     425.0 | 0.195
#     435.0 | 0.310

# %% [markdown]
# <br />
# <br />
#
# ## Add fake data (test detection efficiency):

# %%
#Fake list: add some instances of "750"
mu_lifetime_ns_purified_500_fake = mu_lifetime_ns_purified_500 + [750] * 200




#Fitting---------------------------------------------------------------------------
plt.figure(figsize=(4, 3), dpi=400)

print("\nLeast Square Fitting:==================")

# Define histogram parameters
bin_width = 500
range_min = 500
range_max = 15500
bins = np.arange(range_min, range_max + bin_width, bin_width)

# Create the histogram and capture counts, bin edges, etc.
n, bin_edges, patches = plt.hist(mu_lifetime_ns_purified_500_fake, bins=bins, range=(range_min, range_max),
                                 edgecolor='blue', histtype='step', linewidth=0.8,
                                 label='Muon Lifetime Preliminary')

# Calculate bin centers
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

# Calculate statistical uncertainties (sqrt(n))
yerr = np.sqrt(n)
yerr_plot = np.where(n == 0, 1, yerr)  # Avoid zero division error for empty bins

# Plot error bars on the histogram
plt.errorbar(bin_centers, n, yerr=yerr, fmt='o', color='blue', markersize=2)


# Define the exponential fitting function: N(t) = N0 * exp(-t/tau0) + C
def exp_func(t, N0, tau0, C):
    return N0 * np.exp(-t / tau0) + C

# Least Squares Method------
popt, pcov = curve_fit(exp_func, bin_centers, n, p0=[max(n), 1000, 1], sigma=yerr, absolute_sigma=True)
perr = np.sqrt(np.diag(pcov))  # parameter uncertainties

# Print entries and uncertainties for each bin
print("\nBin information:")
for i in range(len(n)):
    print(f"Bin {i+1}: Range = [{bin_edges[i]:.0f}, {bin_edges[i+1]:.0f}) | "
          f"Center = {bin_centers[i]:.0f} ns | "
          f"Entries = {n[i]:.0f} ± {yerr[i]:.1f}")

# Print results to terminal
print("\nFitted parameters:")
print("N0 = {:.2f} +/- {:.2f}".format(popt[0], perr[0]))
print("tau0 = {:.2f} +/- {:.2f} ns".format(popt[1], perr[1]))
print("C = {:.2f} +/- {:.2f}".format(popt[2], perr[2]))

# Calculate chi-squared
expected = exp_func(bin_centers, *popt)
expected = np.clip(expected, 1e-10, None)  # Avoid division by zero
residuals = n - expected
chi2 = np.sum((residuals / yerr_plot) ** 2)
ndf = len(n) - len(popt)
chi2_ndf = chi2 / ndf

# Print goodness-of-fit summary
print(f"\n[Goodness of Fit] χ² / ndf = {chi2:.1f} / {ndf} = {chi2_ndf:.2f}")

# Print detailed bin-by-bin information
for i, (label, observed, exp_val, res, err) in enumerate(zip(bin_centers, n, expected, residuals, yerr_plot)):
    print(f"Bin {i} (center={label:.2f}): n = {observed:.2f}; expected = {exp_val:.2f}; "
          f"residual = {res:.2f}; residual / yerr = {res / err:.2f}")

# Plot and legend----------
n0_text = f'N₀ = {popt[0]:.0f} ± {perr[0]:.0f}'
tau_text = f'τ = {popt[1]:.0f} ± {perr[1]:.0f} ns'
c_text = f'C = {popt[2]:.1f} ± {perr[2]:.1f}'
chi2_text = f'χ² / ndf = {chi2:.1f} / {ndf}'

t_fit = np.linspace(range_min, range_max, 1000)
fit_line, = plt.plot(t_fit, exp_func(t_fit, *popt), color='red', linestyle='--', label=tau_text)

# Dummy handles for text-only legend entries
dummy_n0 = plt.Line2D([], [], color='none', label=n0_text)
dummy_c = plt.Line2D([], [], color='none', label=c_text)
dummy_chi2 = plt.Line2D([], [], color='none', label=chi2_text)

# Histogram handle
hist_handle = plt.Line2D([], [], color='blue', linestyle='-', label='Muon Lifetime Preliminary')

plt.legend(handles=[hist_handle, fit_line, dummy_n0, dummy_c, dummy_chi2],
           loc='upper center', bbox_to_anchor=(0.7, 0.99),
           fontsize=7, ncol=1, prop={'size': 6})

plt.xlim(0, 16000)
plt.ylim(0.9, 1000)
#plt.yscale('log')
plt.xlabel('Time [ns]', labelpad=2, fontsize=8)
plt.ylabel('#Counts', labelpad=1, fontsize=8)
plt.tick_params(labelsize=7)
plt.grid(color='gray', linestyle='--', linewidth=0.2, zorder=0)
plt.show()
# Out:
# Least Square Fitting:==================
#
# Bin information:
# Bin 1: Range = [500, 1000) | Center = 750 ns | Entries = 824 ± 28.7
# Bin 2: Range = [1000, 1500) | Center = 1250 ns | Entries = 516 ± 22.7
# Bin 3: Range = [1500, 2000) | Center = 1750 ns | Entries = 438 ± 20.9
# Bin 4: Range = [2000, 2500) | Center = 2250 ns | Entries = 407 ± 20.2
# Bin 5: Range = [2500, 3000) | Center = 2750 ns | Entries = 292 ± 17.1
# Bin 6: Range = [3000, 3500) | Center = 3250 ns | Entries = 230 ± 15.2
# Bin 7: Range = [3500, 4000) | Center = 3750 ns | Entries = 178 ± 13.3
# Bin 8: Range = [4000, 4500) | Center = 4250 ns | Entries = 155 ± 12.4
# Bin 9: Range = [4500, 5000) | Center = 4750 ns | Entries = 113 ± 10.6
# Bin 10: Range = [5000, 5500) | Center = 5250 ns | Entries = 99 ± 9.9
# Bin 11: Range = [5500, 6000) | Center = 5750 ns | Entries = 66 ± 8.1
# Bin 12: Range = [6000, 6500) | Center = 6250 ns | Entries = 65 ± 8.1
# Bin 13: Range = [6500, 7000) | Center = 6750 ns | Entries = 67 ± 8.2
# Bin 14: Range = [7000, 7500) | Center = 7250 ns | Entries = 49 ± 7.0
# Bin 15: Range = [7500, 8000) | Center = 7750 ns | Entries = 37 ± 6.1
# Bin 16: Range = [8000, 8500) | Center = 8250 ns | Entries = 42 ± 6.5
# Bin 17: Range = [8500, 9000) | Center = 8750 ns | Entries = 32 ± 5.7
# Bin 18: Range = [9000, 9500) | Center = 9250 ns | Entries = 29 ± 5.4
# Bin 19: Range = [9500, 10000) | Center = 9750 ns | Entries = 33 ± 5.7
# Bin 20: Range = [10000, 10500) | Center = 10250 ns | Entries = 35 ± 5.9
# Bin 21: Range = [10500, 11000) | Center = 10750 ns | Entries = 28 ± 5.3
# Bin 22: Range = [11000, 11500) | Center = 11250 ns | Entries = 23 ± 4.8
# Bin 23: Range = [11500, 12000) | Center = 11750 ns | Entries = 22 ± 4.7
# Bin 24: Range = [12000, 12500) | Center = 12250 ns | Entries = 36 ± 6.0
# Bin 25: Range = [12500, 13000) | Center = 12750 ns | Entries = 41 ± 6.4
# Bin 26: Range = [13000, 13500) | Center = 13250 ns | Entries = 16 ± 4.0
# Bin 27: Range = [13500, 14000) | Center = 13750 ns | Entries = 26 ± 5.1
# Bin 28: Range = [14000, 14500) | Center = 14250 ns | Entries = 24 ± 4.9
# Bin 29: Range = [14500, 15000) | Center = 14750 ns | Entries = 31 ± 5.6
# Bin 30: Range = [15000, 15500) | Center = 15250 ns | Entries = 17 ± 4.1
#
# Fitted parameters:
# N0 = 1079.80 +/- 36.31
# tau0 = 1943.41 +/- 54.11 ns
# C = 22.85 +/- 1.51
#
# [Goodness of Fit] χ² / ndf = 50.9 / 27 = 1.88
# Bin 0 (center=750.00): n = 824.00; expected = 756.93; residual = 67.07; residual / yerr = 2.34
# Bin 1 (center=1250.00): n = 516.00; expected = 590.40; residual = -74.40; residual / yerr = -3.28
# Bin 2 (center=1750.00): n = 438.00; expected = 461.66; residual = -23.66; residual / yerr = -1.13
# Bin 3 (center=2250.00): n = 407.00; expected = 362.11; residual = 44.89; residual / yerr = 2.22
# Bin 4 (center=2750.00): n = 292.00; expected = 285.15; residual = 6.85; residual / yerr = 0.40
# Bin 5 (center=3250.00): n = 230.00; expected = 225.65; residual = 4.35; residual / yerr = 0.29
# Bin 6 (center=3750.00): n = 178.00; expected = 179.65; residual = -1.65; residual / yerr = -0.12
# Bin 7 (center=4250.00): n = 155.00; expected = 144.08; residual = 10.92; residual / yerr = 0.88
# Bin 8 (center=4750.00): n = 113.00; expected = 116.58; residual = -3.58; residual / yerr = -0.34
# Bin 9 (center=5250.00): n = 99.00; expected = 95.32; residual = 3.68; residual / yerr = 0.37
# Bin 10 (center=5750.00): n = 66.00; expected = 78.88; residual = -12.88; residual / yerr = -1.59
# Bin 11 (center=6250.00): n = 65.00; expected = 66.17; residual = -1.17; residual / yerr = -0.15
# Bin 12 (center=6750.00): n = 67.00; expected = 56.34; residual = 10.66; residual / yerr = 1.30
# Bin 13 (center=7250.00): n = 49.00; expected = 48.75; residual = 0.25; residual / yerr = 0.04
# Bin 14 (center=7750.00): n = 37.00; expected = 42.87; residual = -5.87; residual / yerr = -0.97
# Bin 15 (center=8250.00): n = 42.00; expected = 38.33; residual = 3.67; residual / yerr = 0.57
# Bin 16 (center=8750.00): n = 32.00; expected = 34.82; residual = -2.82; residual / yerr = -0.50
# Bin 17 (center=9250.00): n = 29.00; expected = 32.10; residual = -3.10; residual / yerr = -0.58
# Bin 18 (center=9750.00): n = 33.00; expected = 30.01; residual = 2.99; residual / yerr = 0.52
# Bin 19 (center=10250.00): n = 35.00; expected = 28.38; residual = 6.62; residual / yerr = 1.12
# Bin 20 (center=10750.00): n = 28.00; expected = 27.13; residual = 0.87; residual / yerr = 0.16
# Bin 21 (center=11250.00): n = 23.00; expected = 26.16; residual = -3.16; residual / yerr = -0.66
# Bin 22 (center=11750.00): n = 22.00; expected = 25.41; residual = -3.41; residual / yerr = -0.73
# Bin 23 (center=12250.00): n = 36.00; expected = 24.83; residual = 11.17; residual / yerr = 1.86
# Bin 24 (center=12750.00): n = 41.00; expected = 24.38; residual = 16.62; residual / yerr = 2.60
# Bin 25 (center=13250.00): n = 16.00; expected = 24.03; residual = -8.03; residual / yerr = -2.01
# Bin 26 (center=13750.00): n = 26.00; expected = 23.77; residual = 2.23; residual / yerr = 0.44
# Bin 27 (center=14250.00): n = 24.00; expected = 23.56; residual = 0.44; residual / yerr = 0.09
# Bin 28 (center=14750.00): n = 31.00; expected = 23.40; residual = 7.60; residual / yerr = 1.37
# Bin 29 (center=15250.00): n = 17.00; expected = 23.27; residual = -6.27; residual / yerr = -1.52
