# %% [markdown]
# ## Official MC 2025 Production PDS check---
#
# ### --Created by Shu, 20260616

# %%
# Based on minu5GeV dataset:

pdt0_all = []
with open("./PDSt0_all.txt", "r") as f:
    pdt0_all = [float(line.strip()) for line in f]

print(pdt0_all[:10])
print("Total entries:", len(pdt0_all))
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'root_py311 (Python 3.11.15)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
